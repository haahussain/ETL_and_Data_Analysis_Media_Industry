# %%
# First import all libraries/modules we need 
import mysql.connector
from mysql.connector import errorcode 
import config
import requests
import time
## Connect to DB server on AWS
db_name= 'Movies'
cnx = mysql.connector.connect(
    host = config.host,
    user = config.user,
    passwd = config.password,
    
)
cursor = cnx.cursor()
print(cnx)
# Out:
# <mysql.connector.connection.MySQLConnection object at 0x10599cf98>

# %%
## Function to create new DB within AWS 
def create_database(cursor, database):
    try:
        cursor.execute(
            "CREATE DATABASE {} DEFAULT CHARACTER SET 'utf8'".format(database))
    except mysql.connector.Error as err:
        print("Failed creating database: {}".format(err))
        exit(1)
# try to use db we are creating and if it doesnt exist will print does not exist and if that error code
# then it will run except which tries to create the db and will proint created sucessfully. 
try:
    cursor.execute("USE {}".format(db_name))
except mysql.connector.Error as err:
    print("Database {} does not exists.".format(db_name))
    if err.errno == errorcode.ER_BAD_DB_ERROR:
        create_database(cursor, db_name)
        print("Database {} created successfully.".format(db_name))
        cnx.database = db_name
    else:
        print(err)
        exit(1)

# %%
db_name= 'Movies'
# this defines tables/table framework 
TABLES = {}
TABLES['people'] = (
    "CREATE TABLE people ("
    "  personId int NOT NULL AUTO_INCREMENT,"
    "  personName varchar(35) NOT NULL,"     
    "  personRole varchar(10) NOT NULL,"   
    "  PRIMARY KEY (personId),"
    "  UNIQUE KEY  (personName,personRole)" #because we want combination to be repeated, for example 
                                            #role/person can show up multiple times but dont want that 
    ") ENGINE=InnoDB")

# creates junction table 
TABLES['movies_people'] = """CREATE TABLE movies_people ( 
        movieId INT NOT NULL,           
        personId INT NOT NULL,
        PRIMARY KEY (movieId,personId),
        INDEX movieId_idx (movieId ASC),
        CONSTRAINT movieId
            FOREIGN KEY (movieId)
            REFERENCES movies (movieId)
            ON DELETE CASCADE
            ON UPDATE CASCADE,
        CONSTRAINT personId
            FOREIGN KEY (personId)
            REFERENCES people (personId)
            ON DELETE CASCADE
            ON UPDATE CASCADE
) ENGINE=InnoDB;
"""
# cascade means if we delte from one then it can delete from junction too 
# foreign key assigns to junction table and reference calls from the original table

# %%
def create_table(dict_of_tables):
    for table_name in dict_of_tables:
        table_description = dict_of_tables[table_name]
        try:
            print("Creating table {}: ".format(table_name), end='')  
            cursor.execute(table_description)        #executes query
        except mysql.connector.Error as err:        #unless it error which table exists then it will print already exists
            if err.errno == errorcode.ER_TABLE_EXISTS_ERROR:
                print("already exists.")
            else:
                print(err.msg)
        else:
            print("OK")
            
def drop_everything():
    cursor.execute("""DROP TABLE movies_people;""")
    cursor.execute("""DROP TABLE people;""")
    cnx.commit()
    
def close_connections():
    cursor.close()
    cnx.close()

# %%
create_table(TABLES)
# Out:
# Creating table people: already exists.
# Creating table movies_people: already exists.

# %%
#making api call 
# function accepts movies titles as string and movies is a list of strings 
def all_results(movies): 
    results = []
    
    for i in range(len(movies)):
        title = movies[i]
        
        url_params = {'term': title.replace(' ', '+')}
        url = f'http://www.omdbapi.com/?apikey={config.api_key}&t={title}'
        response = requests.get(url, params=url_params)
        results.append(response.json())
        time.sleep(1) # wait a second
    return results

def get_movie_titles():
    cursor.execute("""SELECT movieId, movieTitle FROM movies;""")
    return cursor.fetchall()

# %%
movie_titles = get_movie_titles()
titles_only = [movie_tuple[1].replace('.','') for movie_tuple in movie_titles]
# print(len(movie_titles))
# print(titles_only)
# Out:
# 906
# ['10,000 BC', '102 Dalmatians', '2 Fast 2 Furious', '2 Guns', '2012', '300', '300: Rise of an Empire', '47 Ronin', '50 First Dates', 'A Beautiful Mind', 'A Civil Action', 'A Dogâ\x80\x99s Way Home', 'A Good Day to Die Hard', 'A Sound of Thunder', 'A Wrinkle in Time', 'Abraham Lincoln: Vampire Hunter', 'After Earth', 'After the Sunset', 'Air Force One', 'Air Strike', 'Aladdin', 'Alexander', 'Ali', 'Alice in Wonderland', 'Alice Through the Looking Glass', 'Alien: Covenant', 'Alien: Resurrection', 'Alita: Battle Angel', 'Allied', 'Alvin and the Chipmunks', 'Alvin and the Chipmunks: Chipwrecked', 'Alvin and the Chipmunks: The Road Chip', 'Alvin and the Chipmunks: The Squeakquel', 'American Assassin', 'American Gangster', 'American Sniper', 'American Wedding', 'Analyze That', 'Angels & Demons', 'Anger Management', 'Annie', 'Ant-Man', 'Ant-Man and the Wasp', 'Antz', 'Any Given Sunday', 'Apollo 13', 'Aquaman', 'Armageddon', 'Around the World in 80 Days', 'Arthur Christmas', 'Arthur et les Minimoys', 'Artificial Intelligence: AI', 'Assassinâ\x80\x99s Creed', 'Astro Boy', 'Atlantis: The Lost Empire', 'Austin Powers in Goldmember', 'Australia', 'Avatar', 'Avengers: Age of Ultron', 'Avengers: Endgame', 'Avengers: Infinity War', 'Babe: Pig in the City', 'Bad Boys II', 'Bad Company', 'Bandits', 'Basic Instinct 2', 'Batman & Robin', 'Batman Begins', 'Batman Forever', 'Batman Returns', 'Batman v Superman: Dawn of Justice', 'Battle: Los Angeles', 'Battleship', 'Baywatch', 'Beauty and the Beast', 'Bedtime Stories', 'Bee Movie', 'Ben-Hur', 'Beowulf', 'Bewitched', 'Bicentennial Man', 'Big Hero 6', 'Black Hawk Down', 'Black Panther', 'Blackhat', 'Blade Runner 2049', 'Blade: Trinity', 'Blades of Glory', 'Blood Diamond', 'Body of Lies', 'Bohemian Rhapsody', 'Bolt', 'Brave', 'Braveheart', 'Broken Arrow', 'Bruce Almighty', 'Bumblebee', 'Captain America: Civil War', 'Captain America: The First Avenger', 'Captain America: The Winter Soldier', "Captain Corelli's Mandolin", 'Captain Marvel', 'Captain Phillips', 'Cars', 'Cars 3', 'Casino Royale', 'Cast Away', 'Cats & Dogs', 'Cats & Dogs: The Revenge of Kitty Galore', 'Catwoman', 'Charlie and the Chocolate Factory', "Charlie Wilson's War", "Charlie's Angels", "Charlie's Angels: Full Throttle", "Charlotte's Web", 'Che, Part 1: The Argentine', 'Cheaper by the Dozen 2', 'Chicken Little', 'Children of Men', 'Christopher Robin', 'Cinderella', 'Cinderella Man', 'Clash of the Titans', 'Clear and Present Danger', 'Click', 'Cloud Atlas', 'Cloudy with a Chance of Meatballs', 'Cloudy with a Chance of Meatballs 2', 'Coco', 'Cold Mountain', 'Cold Pursuit', 'Collateral', 'Con Air', 'Conan the Barbarian', 'Constantine', 'Contact', 'Contagion', 'Coraline', 'Couples Retreat', 'Cowboys and Aliens', 'Daddy Day Care', 'Daddyâ\x80\x99s Home 2', 'Daredevil', 'Dark Phoenix', 'Dark Shadows', 'Dark Water', 'Dawn of the Planet of the Apes', 'Days of Thunder', 'DÃ©jÃ\xa0 Vu', 'Deadpool', 'Deadpool 2', 'Death Race', 'Deep Blue Sea', 'Deep Impact', 'Deepwater Horizon', 'Despicable Me', 'Despicable Me 2', 'Despicable Me 3', 'Did You Hear About the Morgans?', 'Die Another Day', 'Die Hard 2', 'Die Hard: With a Vengeance', 'Dinner for Schmucks', 'Dinosaur', 'Disneyâ\x80\x99s A Christmas Carol', 'Divergent', 'Django Unchained', 'Doctor Dolittle', "Doctor Seuss' The Lorax", 'Doctor Strange', 'Downsizing', 'Dr Dolittle 2', 'Dr Seussâ\x80\x99 The Grinch', 'Dracula Untold', 'Dreamcatcher', 'Dreamgirls', 'Driven', 'Due Date', 'Dumbo', 'Dunkirk', 'Duplicity', 'Eagle Eye', 'Eat Pray Love', 'Edge of Darkness', 'Edge of Tomorrow', 'EDtv', 'Elektra', 'Elysium', 'Enchanted', "Ender's Game", 'Enemy at the Gates', 'Enemy of the State', 'Epic', 'Eraser', 'Escape Plan', 'Evan Almighty', 'Everest', 'Evolution', 'Exodus: Gods and Kings', 'Exorcist: The Beginning', 'Face/Off', 'Fantasia 2000 (Theatrical Release)', 'Fantastic Beasts and Where to Find Them', 'Fantastic Beasts: The Crimes of Grindelwald', 'Fantastic Four', 'Fantastic Four: Rise of the Silver S ...

# %%
# raw_movie_data = all_results(titles_only)
# print(len(raw_movie_data) == len(movie_titles))
counter = 0
for temp in raw_movie_data:
#     print(temp)
    if temp['Response'] == 'True': 
        if temp['Title'] in titles_only:
            counter += 1
        else:
            print(temp['Title'])
# Out:
# Batman
# Battle Los Angeles
# Cats
# Cats
# Die Hard with a Vengeance
# Dr. Dolittle 2
# Edtv
# Fast & Furious 6
# Fun with Dick and Jane
# G.I. Joe: Retaliation
# G.I. Joe: The Rise of Cobra
# George of the Jungle
# GoldenEye
# Guardians of the Galaxy Vol. 2
# Horton Hears a Who!
# I Am Legend
# Just Go with It
# Lara Croft Tomb Raider: The Cradle of Life
# Lost in Space
# Marley
# Pen huo mei ren yu
# All Access: Making Michael Jackson's This Is It
# Mission: Impossible - Ghost Protocol
# Monsters vs. Aliens
# Monsters, Inc.
# Mr. and Mrs. Smith
# Mr. Peabody & Sherman
# Percy Jackson
# R.I.P.D.
# Ralph Breaks the Internet
# RED
# S.W.A.T.
# Scott Pilgrim vs. the World
# Spider-Man: Far from Home
# You Nazty Spy!
# Terminator Genisys
# The Lego Movie 2: The Second Part
# The Man from U.N.C.L.E.
# The Twilight Saga: Breaking Dawn - Part 1
# The Twilight Saga: Breaking Dawn - Part 2
# The World Is Not Enough
# TRON: Legacy
# Underworld Awakening
# Up Close
# WALL·E
# Warcraft: The Beginning
# Who Framed Roger Rabbit
# xXx: State of the Union
# You Don't Mess with the Zohan
# Zathura: A Space Adventure

# %%
def moviesfromOM(initialdata):
    movies=[]
    for movie in initialdata:
        if movie['Response'] == 'True':
            movieinfo={}
            movieinfo['Title']=movie['Title']
            movieinfo["Director"]=[director.strip() for director in movie['Director'].split(',')] # how does it add quotation to each? 
            movieinfo['Writer']=[writer.split('(')[0].strip() for writer in movie['Writer'].split(',')]
            #movieinfo['Writer'] = movie['Writer'].split(',')
            movieinfo['Actors']=[actor.strip() for actor in movie['Actors'].split(',')]
            movies.append(movieinfo)
    return movies

# %%
movie_data = moviesfromOM(raw_movie_data)
movie_data
# Out:
# [{'Title': '10,000 BC',
#   'Director': ['Roland Emmerich'],
#   'Writer': ['Roland Emmerich', 'Harald Kloser'],
#   'Actors': ['Steven Strait', 'Camilla Belle', 'Cliff Curtis', 'Joel Virgel']},
#  {'Title': '102 Dalmatians',
#   'Director': ['Kevin Lima'],
#   'Writer': ['Dodie Smith',
#    'Kristen Buckley',
#    'Brian Regan',
#    'Kristen Buckley',
#    'Brian Regan',
#    'Bob Tzudiker',
#    'Noni White'],
#   'Actors': ['Glenn Close',
#    'Gérard Depardieu',
#    'Ioan Gruffudd',
#    'Alice Evans']},
#  {'Title': '2 Fast 2 Furious',
#   'Director': ['John Singleton'],
#   'Writer': ['Gary Scott Thompson',
#    'Michael Brandt',
#    'Derek Haas',
#    'Gary Scott Thompson',
#    'Michael Brandt',
#    'Derek Haas'],
#   'Actors': ['Paul Walker', 'Tyrese Gibson', 'Eva Mendes', 'Cole Hauser']},
#  {'Title': '2 Guns',
#   'Director': ['Baltasar Kormákur'],
#   'Writer': ['Blake Masters', 'Steven Grant'],
#   'Actors': ['Denzel Washington',
#    'Mark Wahlberg',
#    'Paula Patton',
#    'Edward James Olmos']},
#  {'Title': '2012',
#   'Director': ['Roland Emmerich'],
#   'Writer': ['Roland Emmerich', 'Harald Kloser'],
#   'Actors': ['John Cusack',
#    'Amanda Peet',
#    'Chiwetel Ejiofor',
#    'Thandie Newton']},
#  {'Title': '300',
#   'Director': ['Zack Snyder'],
#   'Writer': ['Zack Snyder',
#    'Kurt Johnstad',
#    'Michael B. Gordon',
#    'Frank Miller',
#    'Lynn Varley'],
#   'Actors': ['Gerard Butler', 'Lena Headey', 'Dominic West', 'David Wenham']},
#  {'Title': '300: Rise of an Empire',
#   'Director': ['Noam Murro'],
#   'Writer': ['Zack Snyder', 'Kurt Johnstad', 'Frank Miller'],
#   'Actors': ['Sullivan Stapleton',
#    'Eva Green',
#    'Lena Headey',
#    'Hans Matheson']},
#  {'Title': '47 Ronin',
#   'Director': ['Carl Rinsch'],
#   'Writer': ['Chris Morgan', 'Hossein Amini', 'Chris Morgan', 'Walter Hamada'],
#   'Actors': ['Keanu Reeves',
#    'Hiroyuki Sanada',
#    'Ko Shibasaki',
#    'Tadanobu Asano']},
#  {'Title': '50 First Dates',
#   'Director': ['Peter Segal'],
#   'Writer': ['George Wing'],
#   'Actors': ['Adam Sandler', 'Drew Barrymore', 'Rob Schneider', 'Sean Astin']},
#  {'Title': 'A Beautiful Mind',
#   'Director': ['Ron Howard'],
#   'Writer': ['Akiva Goldsman', 'Sylvia Nasar'],
#   'Actors': ['Russell Crowe',
#    'Ed Harris',
#    'Jennifer Connelly',
#    'Christopher Plummer']},
#  {'Title': 'A Civil Action',
#   'Director': ['Steven Zaillian'],
#   'Writer': ['Jonathan Harr', 'Steven Zaillian'],
#   'Actors': ['John Travolta',
#    'Robert Duvall',
#    'Tony Shalhoub',
#    'William H. Macy']},
#  {'Title': 'A Good Day to Die Hard',
#   'Director': ['John Moore'],
#   'Writer': ['Skip Woods', 'Roderick Thorp'],
#   'Actors': ['Bruce Willis',
#    'Jai Courtney',
#    'Sebastian Koch',
#    'Mary Elizabeth Winstead']},
#  {'Title': 'A Sound of Thunder',
#   'Director': ['Peter Hyams'],
#   'Writer': ['Ray Bradbury',
#    'Thomas Dean Donnelly',
#    'Joshua Oppenheimer',
#    'Thomas Dean Donnelly',
#    'Joshua Oppenheimer',
#    'Gregory Poirier'],
#   'Actors': ['Armin Rohde',
#    'Heike Makatsch',
#    'Jemima Rooper',
#    'David Oyelowo']},
#  {'Title': 'A Wrinkle in Time',
#   'Director': ['Ava DuVernay'],
#   'Writer': ['Jennifer Lee', 'Jeff Stockwell', "Madeleine L'Engle"],
#   'Actors': ['Storm Reid',
#    'Oprah Winfrey',
#    'Reese Witherspoon',
#    'Mindy Kaling']},
#  {'Title': 'Abraham Lincoln: Vampire Hunter',
#   'Director': ['Timur Bekmambetov'],
#   'Writer': ['Seth Grahame-Smith', 'Seth Grahame-Smith'],
#   'Actors': ['Benjamin Walker',
#    'Dominic Cooper',
#    'Anthony Mackie',
#    'Mary Elizabeth Winstead']},
#  {'Title': 'After Earth',
#   'Director': ['M. Night Shyamalan'],
#   'Writer': ['Gary Whitta', 'M. Night Shyamalan', 'Will Smith'],
#   'Actors': ['Jaden Smith', 'Will Smith', 'Sophie Okonedo', 'Zoë Kravitz']},
#  {'Title': 'After the Sunset',
#   'Director': ['Brett Ratner'],
#   'Writer': ['Paul Zbyszewski', 'Paul Zbyszewski', 'Craig Rosenberg'],
#   'Actors': ['Pierce Brosnan',
#    'Salma Hayek',
#    'Woody Harrelson',
#    'Don Cheadle']},
#  {'Title': 'Air Force One',
#   'Director': ['Wolfgang Petersen'],
#   'Writer': ['Andrew W. Marlowe'],
#   'Actors': ['Harrison Ford', 'Gary Oldman', 'Glenn Close', 'Wendy Crewson']},
#  {'Title': 'Air Strike',
#   'Director': ['Xiao Feng'],
#   'Writer': ['Ping Chen', 'Tie Dong Zhou'],
#   'Actors': ['Ye Liu',
#    'Bruce Willis',
#    'Seung-heon Song',
#    'William Wai-Ting Chan']},
#  {'Title': 'Aladdin',
#   'Director': ['Ron Clements', 'John Musker'],
#   'Writer': ['Ron Clements',
#    'John Musker',
#    'Ted Elliott',
#    'Terry Rossio',
#    'Burny Mattinson',
#    'Roger Allers',
#    'Daan Jippes',
#    'Kevin Harkey',
#    'Sue C. Nichols',
#    'Francis Glebas',
#    'Darrell Rooney',
#    'Larry Leker',
#    'James Fujii',
#    'Kirk Hanson',
#    'Kevin Lima',
#    'Rebecca Rees',
#    'David S. Smith',
#    'Chris Sanders',
#    'Brian Pimental',
#    'Patrick A. Ventura'],
#   'Actors': ['Scott Weinger',
#    'Robin Williams',
#    'Linda Larkin',
#    'Jonathan Freeman']},
#  {'Title': 'Alexander',
#   'Director': ['Oliver Stone'],
#   'Writer': ['Oliver Stone', 'Christopher Kyle', 'Laeta Kalogridis'],
#   'Actors': ['Anthony Hopkins',
#    'David Bedella',
#    'Jessie Kamm',
#    'Angelina Jolie']},
#  {'Title': 'Ali',
#   'Director': ['Michael Mann'],
#   'Writer': ['Gregory Allen Howard',
#    'Stephen J. Rivele',
#    'Christopher Wilkinson',
#    'Eric Roth',
#    'Michael Mann'],
#   'Actors': ['Will Smith', 'Jamie Foxx', 'Jon Voight', 'Mario Van Peebles']},
#  {'Title': 'Alice in Wonderland',
#   'Director': ['Tim Burton'],
#   'Writer': ['Linda Woolverton', 'Lewis Carroll'],
#   'Actors': ['Johnny Depp',
#    'Mia Wasikowska',
#    'Helena Bonham Carter',
#    'Anne Hathaway']},
#  {'Title': 'Alice Through the Looking Glass',
#   'Director': ['James Bobin'],
#   'Writer': ['Linda Woolverton', 'Lewis Carroll'],
#   'Actors': ['Johnny Depp',
#    'Mia Wasikowska',
#    'Helena Bonham Carter',
#    'Anne Hathaway']},
#  {'Title': 'Alien: Covenant',
#   'Director': ['Ridley Scott'],
#   'Writer': ["Dan O'Bannon",
#    'Ronald Shusett',
#    'Jack Paglen',
#    'Michael Green',
#    'John Logan',
#    'Dante Harper'],
#   'Actors': ['Michael Fassbender',
#    'Katherine Waterston',
#    'Billy Crudup',
#    'Danny McBride']},
#  {'Title': 'Alien: Resurrection',
#   'Director': ['Jean-Pierre Jeunet'],
#   'Writer': ["Dan O'Bannon", 'Ronald Shusett', 'Joss Whedon'],
#   'Actors': ['Sigourney Weaver',
#    'Winona Ryder',
#    'Dominique Pinon',
#    'Ron Perlman']},
#  {'Title': 'Alita: Battle Angel',
#   'Director': ['Robert Rodriguez'],
#   'Writer': ['James Cameron', 'Laeta Kalogridis', 'Yukito Kishiro'],
#   'Actors': ['Rosa Salazar',
#    'Christoph Waltz',
#    'Jennifer Connelly',
#    'Mahershala Ali']},
#  {'Title': 'Allied',
#   'Director': ['Robert Zemeckis'],
#   'Writer': ['Steven Knight'],
#   'Actors': ['Brad Pitt',
#    'Vincent Ebrahim',
#    'Xavier de Guillebon',
#    'Marion Cotillard']},
#  {'Title': 'Alvin and the Chipmunks',
#   'Director': ['Tim Hill'],
#   'Writer': ['Jon Vitti',
#    'Will McRobb',
#    'Chris Viscardi',
#    'Jon Vitti',
#    'Ross Bagdasarian'],
#   'Actors': ['Jason Lee', 'David Cross', 'Cameron Richardson', 'Jane Lynch']},
#  {'Title': 'Alvin and the Chipmunks: Chipwrecked',
#   'Director': ['Mike Mitchell'],
#   'Writer': ['Jonathan Aibel',
#    'Glenn Berger',
#    'Ross Bagdasarian',
#    'Janice Karman'],
#   'Actors': ['Jason Lee', 'David Cross', 'Jenny Slate', 'Justin Long']},
#  {'Title': 'Alvin and the Chipmunks: The Road Chip',
#   'Director': ['Walt Becker'],
#   'Writer': ['Ross Bagdasarian',
#    'Janice Karman',
#    'Randi Mayem Singer',
#    'Adam Sztykiel'],
#   'Actors': ['Jason Lee',
#    'Justin Long',
#    'Matthew Gray Gubler',
#    'Jesse McCartney']},
#  {'Title': 'Alvin and the Chipmunks: The Squeakquel',
#   'Director': ['Betty Thomas'],
#   'Writer': ['Jon Vitti',
#    'Jonathan Aibel',
#    'Glenn Berger',
#    'Ross Bagdasarian'],
#   'Actors': ['Zachary Levi', 'David Cross', 'Jason Lee', 'Justin Long']},
#  {'Title': 'American Assassin',
#   'Director': ['Michael Cuesta'],
#   'Writer': ['Stephen Schiff',
#    'Michael Finch',
#    'Edward Zwick',
#    'Marshall Herskovitz',
#    'Vince Flynn'],
#   'Actors': ["Dylan O'Brien",
#    'Charlotte Vega',
#    'Christopher Bomford',
#    'Chris Webster']},
#  {'Title': 'American Gangster',
#   'Director': ['Ridley Scott'],
#   'Writer': ['Steven Zaillian', 'Mark Jacobson'],
#   'Actors': ['Denzel Washington',
#    'Russell Crowe',
#    'Chiwetel Ejiofor',
#    'Josh Brolin']},
#  {'Title': 'American Sniper',
#   'Director': ['Clint Eastwood'],
#   'Writer': ['Jason Hall', 'Chris Kyle', 'Scott McEwen', 'Jim DeFelice'],
#   'Actors': ['Bradley Cooper', 'Kyle Gallner', 'Cole Konis', 'Ben Reed']},
#  {'Title': 'American Wedding',
#   'Director': ['Jesse Dylan'],
#   'Writer': ['Adam Herz', 'Adam Herz'],
#   'Actors': ['Jason Biggs',
#    'Seann William Scott',
#    'Alyson Hannigan',
#    'Eddie Kaye Thomas']},
#  {'Title': 'Analyze That',
#   'Director': ['Harold Ramis'],
#   'Writer': ['Kenneth Lonergan',
#    'Peter Tolan',
#    'Peter Steinfeld',
#    'Harold Ramis',
#    'Peter Tolan'],
#   'Actors': ['Robert De Niro',
#    'Billy Crystal',
#    'Lisa Kudrow',
#    'Joe Viterelli']},
#  {'Title': 'Angels & Demons',
#   'Director': ['Ron Howard'],
#   'Writer': ['David Koepp', 'Akiva Goldsman', 'Dan Brown'],
#   'Actors': ['Tom Hanks',
#    'Ewan McGregor',
#    'Ayelet Zurer',
#    'Stellan Skarsgård']},
#  {'Title': 'Anger Management',
#   'Director': ['Peter Segal'],
#   'Writer': ['David Dorfman'],
#   'Actors': ['Adam Sandler', 'Jack Nicholson', 'Marisa Tomei', 'Luis Guzmán']},
#  {'Title': 'Annie',
#   'Director': ['John Huston'],
#   'Writer': ['Carol Sobieski', 'Thomas Meehan', 'Martin Charnin'],
#   'Actors': ['Albert Finney', 'Carol Burnett', 'Ann Reinking', 'Tim Curry']},
#  {'Title': 'Ant-Man',
#   'Director': ['Peyton Reed'],
#   'Writer': ['Edgar Wright',
#    'Joe Cornish',
#    'Adam McKay',
#    'Paul Rudd',
#    'Edgar Wright',
#    'Joe Cornish',
#    'Stan Lee',
#    'Larry Lieber',
#    'Jack Kirby'],
#   'Actors': ['Paul Rudd',
#    'Michael Douglas',
#    'Evangeline Lilly',
#    'Corey Stoll']},
#  {'Title': 'Ant-Man and the Wasp',
#   'Director': ['Peyton Reed'],
#   'Writer': ['Chris McKenna',
#    'Erik Sommers',
#    'Paul Rudd',
#    'Andrew Barrer',
#    'Gabriel Ferrari',
#    'Stan Lee',
#    'Larry Lieber',
#    'Jack Kirby'],
#   'Actors': ['Paul Rudd',
#    'Evangeline Lilly',
#    'Michael Peña',
#    'Walton Goggins']},
#  {'Title': 'Antz',
#   'Director': ['Eric Darnell', 'Tim Johnson'],
#   'Writer': ['Todd Alcott', 'Chris Weitz', 'Paul Weitz'],
#   'Actors': ['Woody Allen', 'Dan Aykroyd', 'Anne Bancroft', 'Jane Curtin']},
#  {'Title': 'Any Given Sunday',
#   'Director': ['Oliver Stone'],
#   'Writer': ['Daniel Pyne', 'John Logan', 'John Logan', 'Oliver Stone'],
#   'Actors': ['Al Pacino', 'Cameron Diaz', 'Dennis Quaid', 'James Woods']},
#  {'Title': 'Apollo 13',
#   'Director': ['Ron Howard'],
#   'Writer': ['Jim Lovell',
#    'Jeffrey Kluger',
#    'William Broyles Jr.',
#    'Al Reinert'],
#   'Actors': ['Tom Hanks', 'Bill Paxton', 'Kevin Bacon', 'Gary Sinise']},
#  {'Title': 'Aquaman',
#   'Director': ['James Wan'],
#   'Writer': ['David Leslie Johnson-McGoldrick',
#    'Will Beall',
#    'Geoff Johns',
#    'James Wan',
#    'Will Beall',
#    'Paul Norris',
#    'Mort Weisinger'],
#   'Actors': ['Jason Momoa', 'Amber Heard', 'Willem Dafoe', 'Patrick Wilson']},
#  {'Title': 'Armageddon',
#   'Director': ['Michael Bay'],
#   'Writer': ['Jonathan Hensleigh',
#    'J.J. Abrams',
#    'Tony Gilroy',
#    'Shane Salerno',
#    'Robert Roy Pool',
#    'Jonathan Hensleigh'],
#   'Actors': ['Bruce Willis',
#    'Billy Bob Thornton',
#    'Ben Affleck',
#    'Liv Tyler']},
#  {'Title': 'Around the World in 80 Days',
#   'Director': ['Frank Coraci'],
#   'Writer': ['Jules Verne',
#    'David N. Titcher',
#    'David Benullo',
#    'David Andrew Goldstein'],
#   'Actors': ['Jackie Chan',
#    'Steve Coogan',
#    'Cécile de France',
#    'Robert Fyfe']},
#  {'Title': 'Arthur Christmas',
#   'Director': ['Sarah Smith', 'Barry Cook(co-director)'],
#   'Writer': ['Peter Baynham', 'Sarah Smith'],
#   'Actors': ['James McAvoy', 'Hugh Laurie', 'Bill Nighy', 'Jim Broadbent']},
#  {'Title': 'Astro Boy',
#   'Director': ['David Bowers'],
#   'Writer': ['Osamu Tezuka', 'David Bowers', 'Timothy Harris', 'David Bowers'],
#   'Actors': ['Charlize Theron',
#    'Freddie Highmore',
#    'Ryan Stiles',
#    'Eugene Levy']},
#  {'Title': 'Atlantis: The Lost Empire',
#   'Director': ['Gary Trousdale', 'Kirk Wise'],
#   'Writer': ['Tab Murphy',
#    'Kirk Wise',
#    'Gary Trousdale',
#    'Joss Whedon',
#    'Bryce Zabel',
#    'Jackie Zabel',
#    'Tab Murphy',
#    'David Reynolds'],
#   'Actors': ['Corey Burton',
#    'Claudia Christian',
#    'Michael J. Fox',
#    'James Garner']},
#  {'Title': 'Austin Powers in Goldmember',
#   'Director': ['Jay Roach'],
#   'Writer': ['Mike Myers', 'Michael McCullers', 'Mike Myers'],
#   'Actors': ['Mike Myers', 'Beyoncé', 'Seth Green', 'Michael York']},
#  {'Title': 'Australia',
#   'Director': ['Baz Luhrmann'],
#   'Writer': ['Stuart Beattie',
#    'Baz Luhrmann',
#    'Ronald Harwood',
#    'Richard Flanagan',
#    'Baz Luhrmann'],
#   'Actors': ['Shea Adams', 'Eddie Baroo', 'Ray Barrett', 'Tony Barry']},
#  {'Title': 'Avatar',
#   'Director': ['James Cameron'],
#   'Writer': ['James Cameron'],
#   'Actors': ['Sam Worthington',
#    'Zoe Saldana',
#    'Sigourney Weaver',
#    'Stephen Lang']},
#  {'Title': 'Avengers: Age of Ultron',
#   'Director': ['Joss Whedon'],
#   'Writer': ['Joss Whedon',
#    'Stan Lee',
#    'Jack Kirby',
#    'Joe Simon',
#    'Jack Kirby',
#    'Jim Starlin'],
#   'Actors': ['Robert Downey Jr.',
#    'Chris Hemsworth',
#    'Mark Ruffalo',
#    'Chris Evans']},
#  {'Title': 'Avengers: Endgame',
#   'Director': ['Anthony Russo', 'Joe Russo'],
#   'Writer': ['Christopher Markus',
#    'Stephen McFeely',
#    'Stan Lee',
#    'Jack Kirby',
#    'Jim Starlin',
#    'Gamora & Drax created by)',
#    'Jack Kirby'],
#   'Actors': ['Robert Downey Jr.',
#    'Chris Evans',
#    'Mark Ruffalo',
#    'Chris Hemsworth']},
#  {'Title': 'Avengers: Infinity War',
#   'Director': ['Anthony Russo', 'Joe Russo'],
#   'Writer': ['Christopher Markus',
#    'Stephen McFeely',
#    'Stan Lee',
#    'Jack Kirby',
#    'Joe Simon',
#    'Jack Kirby',
#    'Steve Englehart',
#    'Steve Gan',
#    'Bill Mantlo',
#    'Keith Giffen',
#    'Jim Starlin',
#    'Gamora and Drax created by)',
#    'Stan Lee',
#    'Larry Lieber',
#    'Jack Kirby',
#    'Steve Englehart',
#    'Don Heck'],
#   'Actors': ['Robert Downey Jr.',
#    'Chris Hemsworth',
#    'Mark Ruffalo',
#    'Chris Evans']},
#  {'Title': 'Babe: Pig in the City',
#   'Director': ['George Miller'],
#   'Writer': ['George Miller',
#    'Judy Morris',
#    'Mark Lamprell',
#    'Dick King-Smith'],
#   'Actors': ['Magda Szubanski',
#    'James Cromwell',
#    'Mary Stein',
#    'Mickey Rooney']},
#  {'Title': 'Bad Boys II',
#   'Director': ['Michael Bay'],
#   'Writer': ['George Gallo',
#    'Marianne Wibberley',
#    'Cormac Wibberley',
#    'Ron Shelton',
#    'Ron Shelton',
#    'Jerry Stahl'],
#   'Actors': ['Martin Lawrence',
#    'Will Smith',
#    'Jordi Mollà',
#    'Gabrielle Union']},
#  {'Title': 'Bad Company',
#   'Director': ['Joel Schumacher'],
#   'Writer': ['Gary M. Goodman',
#    'David Himmelstein',
#    'Jason Richman',
#    'Michael Browning'],
#   'Actors': ['Anthony Hopkins',
#    'Chris Rock',
#    'Peter Stormare',
#    'Gabriel Macht']},
#  {'Title': 'Bandits',
#   'Director': ['Barry Levinson'],
#   'Writer': ['Harley Peyton'],
#   'Actors': ['Bruce Willis',
#    'Billy Bob Thornton',
#    'Cate Blanchett',
#    'Troy Garity']},
#  {'Title': 'Basic Instinct 2',
#   'Director': ['Michael Caton-Jones'],
#   'Writer': ['Leora Barish', 'Henry Bean', 'Joe Eszterhas'],
#   'Actors': ['Stan Collymore',
#    'Sharon Stone',
#    'Neil Maskell',
#    'David Thewlis']},
#  {'Title': 'Batman',
#   'Director': ['Tim Burton'],
#   'Writer': ['Bob Kane', 'Sam Hamm', 'Sam Hamm', 'Warren Skaaren'],
#   'Actors': ['Michael Keaton',
#    'Jack Nicholson',
#    'Kim Basinger',
#    'Robert Wuhl']},
#  {'Title': 'Batman Begins',
#   'Director': ['Christopher Nolan'],
#   'Writer': ['Bob Kane',
#    'David S. Goyer',
#    'Christopher Nolan',
#    'David S. Goyer'],
#   'Actors': ['Christian Bale',
#    'Michael Caine',
#    'Liam Neeson',
#    'Katie Holmes']},
#  {'Title': 'Batman Forever',
#   'Director': ['Joel Schumacher'],
#   'Writer': ['Bob Kane',
#    'Lee Batchler',
#    'Janet Scott Batchler',
#    'Lee Batchler',
#    'Janet Scott Batchler',
#    'Akiva Goldsman'],
#   'Actors': ['Val Kilmer', 'Tommy Lee Jones', 'Jim Carrey', 'Nicole Kidman']},
#  {'Title': 'Batman Returns',
#   'Director': ['Tim Burton'],
#   'Writer': ['Bob Kane', 'Daniel Waters', 'Sam Hamm', 'Daniel Waters'],
#   'Actors': ['Michael Keaton',
#    'Danny DeVito',
#    'Michelle Pfeiffer',
#    'Christopher Walken']},
#  {'Title': 'Batman v Superman: Dawn of Justice',
#   'Director': ['Zack Snyder'],
#   'Writer': ['Chris Terrio',
#    'David S. Goyer',
#    'Bob Kane',
#    'Bill Finger',
#    'Jerry Siegel',
#    'Joe Shuster',
#    'William Moulton Marston'],
#   'Actors': ['Ben Affleck', 'Henry Cavill', 'Amy Adams', 'Jesse Eisenberg']},
#  {'Title': 'Battle Los Angeles',
#   'Director': ['Jonathan Liebesman'],
#   'Writer': ['Christopher Bertolini'],
#   'Actors': ['Aaron Eckhart',
#    'Ramon Rodriguez',
#    'Will Rothhaar',
#    'Cory Hardrict']},
#  {'Title': 'Battleship',
#   'Director': ['Peter Berg'],
#   'Writer': ['Jon Hoeber', 'Erich Hoeber'],
#   'Actors': ['Taylor Kitsch',
#    'Alexander Skarsgård',
#    'Rihanna',
#    'Brooklyn Decker']},
#  {'Title': 'Baywatch',
#   'Director': ['Seth Gordon'],
#   'Writer': ['Michael Berk',
#    'Douglas Schwartz',
#    'Gregory J. Bonann',
#    'Jay Scherick',
#    'David Ronn',
#    'Thomas Lennon',
#    'Robert Ben Garant',
#    'Damian Shannon',
#    'Mark Swift'],
#   'Actors': ['Dwayne Johnson',
#    'Zac Efron',
#    'Priyanka Chopra',
#    'Alexandra Daddario']},
#  {'Title': 'Beauty and the Beast',
#   'Director': ['Gary Trousdale', 'Kirk Wise'],
#   'Writer': ['Linda Woolverton',
#    'Brenda Chapman',
#    'Chris Sanders',
#    'Burny Mattinson',
#    'Kevin Harkey',
#    'Brian Pimental',
#    'Bruce Woodside',
#    'Joe Ranft',
#    'Tom Ellery',
#    'Kelly Asbury',
#    'Robert Lence'],
#   'Actors': ['Robby Benson',
#    'Jesse Corti',
#    'Rex Everhart',
#    'Angela Lansbury']},
#  {'Title': 'Bedtime Stories',
#   'Director': ['Adam Shankman'],
#   'Writer': ['Matt Lopez', 'Tim Herlihy', 'Matt Lopez'],
#   'Actors': ['Adam Sandler', 'Keri Russell', 'Guy Pearce', 'Russell Brand']},
#  {'Title': 'Bee Movie',
#   'Director': ['Simon J. Smith', 'Steve Hickner'],
#   'Writer': ['Jerry Seinfeld',
#    'Spike Feresten',
#    'Barry Marder',
#    'Andy Robin',
#    'Chuck Martin',
#    'Tom Papa'],
#   'Actors': ['Jerry Seinfeld',
#    'Renée Zellweger',
#    'Matthew Broderick',
#    'Patrick Warburton']},
#  {'Title': 'Ben-Hur',
#   'Director': ['William Wyler'],
#   'Writer': ['Lew Wallace', 'Karl Tunberg'],
#   'Actors': ['Charlton Heston',
#    'Jack Hawkins',
#    'Haya Harareet',
#    'Stephen Boyd']},
#  {'Title': 'Beowulf',
#   'Director': ['Robert Zemeckis'],
#   'Writer': ['Neil Gaiman', 'Roger Avary', 'Anonymous'],
#   'Actors': ['Robin Wright',
#    'Anthony Hopkins',
#    'Paul Baker',
#    'John Bilezikjian']},
#  {'Title': 'Bewitched',
#   'Director': ['Nora Ephron'],
#   'Writer': ['Nora Ephron', 'Delia Ephron', 'Sol Saks'],
#   'Actors': ['Nicole Kidman',
#    'Will Ferrell',
#    'Shirley MacLaine',
#    'Michael Caine']},
#  {'Title': 'Bicentennial Man',
#   'Director': ['Chris Columbus'],
#   'Writer': ['Isaac Asimov',
#    'Isaac Asimov',
#    'Robert Silverberg',
#    'Nicholas Kazan'],
#   'Actors': ['Robin Williams', 'Embeth Davidtz', 'Sam Neill', 'Oliver Platt']},
#  {'Title': 'Big Hero 6',
#   'Director': ['Don Hall', 'Chris Williams'],
#   'Writer': ['Jordan Roberts',
#    'Robert L. Baird',
#    'Daniel Gerson',
#    'Man of Action',
#    'Steven T. Seagle',
#    'Duncan Rouleau'],
#   'Actors': ['Scott Adsit', 'Ryan Potter', 'Daniel Henney', 'T.J. Miller']},
#  {'Title': 'Black Hawk Down',
#   'Director': ['Ridley Scott'],
#   'Writer': ['Mark Bowden', 'Ken Nolan'],
#   'Actors': ['Josh Hartnett', 'Ewan McGregor', 'Tom Sizemore', 'Eric Bana']},
#  {'Title': 'Black Panther',
#   'Director': ['Ryan Coogler'],
#   'Writer': ['Ryan Coogler', 'Joe Robert Cole', 'Stan Lee', 'Jack Kirby'],
#   'Actors': ['Chadwick Boseman',
#    'Michael B. Jordan',
#    "Lupita Nyong'o",
#    'Danai Gurira']},
#  {'Title': 'Blackhat',
#   'Director': ['Michael Mann'],
#   'Writer': ['Morgan Davis Foehl'],
#   'Actors': ['Chris Hemsworth', 'Leehom Wang', 'Wei Tang', 'Viola Davis']},
#  {'Title': 'Blade Runner 2049',
#   'Director': ['Denis Villeneuve'],
#   'Writer': ['Hampton Fancher',
#    'Michael Green',
#    'Hampton Fancher',
#    'Philip K. Dick'],
#   'Actors': ['Ryan Gosling', 'Dave Bautista', 'Robin Wright', 'Mark Arnold']},
#  {'Title': 'Blade: Trinity',
#   'Director': ['David S. Goyer'],
#   'Writer': ['David S. Goyer', 'Marv Wolfman', 'Gene Colan'],
#   'Actors': ['Wesley Snipes',
#    'Kris Kristofferson',
#    'Dominic Purcell',
#    'Jessica Biel']},
#  {'Title': 'Blades of Glory',
#   'Director': ['Josh Gordon', 'Will Speck'],
#   'Writer': ['Jeff Cox',
#    'Craig Cox',
#    'John Altschuler',
#    'Dave Krinsky',
#    'Craig Cox',
#    'Jeff Cox',
#    'Busy Philipps'],
#   'Actors': ['Will Ferrell', 'Jon Heder', 'Will Arnett', 'Amy Poehler']},
#  {'Title': 'Blood Diamond',
#   'Director': ['Edward Zwick'],
#   'Writer': ['Charles Leavitt', 'Charles Leavitt', 'C. Gaby Mitchell'],
#   'Actors': ['Leonardo DiCaprio',
#    'Djimon Hounsou',
#    'Jennifer Connelly',
#    'Kagiso Kuypers']},
#  {'Title': 'Body of Lies',
#   'Director': ['Ridley Scott'],
#   'Writer': ['William Monahan', 'David Ignatius'],
#   'Actors': ['Leonardo DiCaprio',
#    'Russell Crowe',
#    'Mark Strong',
#    'Golshifteh Farahani']},
#  {'Title': 'Bohemian Rhapsody',
#   'Director': ['Bryan Singer'],
#   'Writer': ['Anthony McCarten', 'Peter Morgan', 'Anthony McCarten'],
#   'Actors': ['Rami Malek', 'Lucy Boynton', 'Gwilym Lee', 'Ben Hardy']},
#  {'Title': 'Bolt',
#   'Director': ['Byron Howard', 'Chris Williams'],
#   'Writer': ['Dan Fogelman', 'Chris Williams'],
#   'Actors': ['John Travolta', 'Miley Cyrus', 'Susie Essman', 'Mark Walton']},
#  {'Title': 'Brave',
#   'Director': ['Mark Andrews', 'Brenda Chapman', 'Steve Purcell(co-director)'],
#   'Writer': ['Brenda Chapman',
#    'Mark Andrews',
#    'Steve Purcell',
#    'Brenda Chapman',
#    'Irene Mecchi'],
#   'Actors': ['Kelly Macdonald',
#    'Billy Connolly',
#    'Emma Thompson',
#    'Julie Walters']},
#  {'Title': 'Braveheart',
#   'Director': ['Mel Gibson'],
#   'Writer': ['Randall Wallace'],
#   'Actors': ['James Robinson', 'Sean Lawlor', 'Sandy Nelson', 'James Cosmo']},
#  {'Title': 'Broken Arrow',
#   'Director': ['John Woo'],
#   'Writer': ['Graham Yost'],
#   'Actors': ['John Travolta',
#    'Christian Slater',
#    'Samantha Mathis',
#    'Delroy Lindo']},
#  {'Title': 'Bruce Almighty',
#   'Director': ['Tom Shadyac'],
#   'Writer': ['Steve Koren',
#    "Mark O'Keefe",
#    'Steve Koren',
#    "Mark O'Keefe",
#    'Steve Oedekerk'],
#   'Actors': ['Jim Carrey',
#    'Morgan Freeman',
#    'Jennifer Aniston',
#    'Philip Baker Hall']},
#  {'Title': 'Bumblebee',
#   'Director': ['Travis Knight'],
#   'Writer': ['Christina Hodson'],
#   'Actors': ['Hailee Steinfeld',
#    'Jorge Lendeborg Jr.',
#    'John Cena',
#    'Jason Drucker']},
#  {'Title': 'Captain America: Civil War',
#   'Director': ['Anthony Russo', 'Joe Russo'],
#   'Writer': ['Christopher Markus',
#    'Stephen McFeely',
#    'Joe Simon',
#    'Jack Kirby'],
#   'Actors': ['Chris Evans',
#    'Robert Downey Jr.',
#    'Scarlett Johansson',
#    'Sebastian Stan']},
#  {'Title': 'Captain America: The First Avenger',
#   'Director': ['Joe Johnston'],
#   'Writer': ['Christopher Markus',
#    'Stephen McFeely',
#    'Joe Simon',
#    'Jack Kirby'],
#   'Actors': ['Chris Evans',
#    'Hayley Atwell',
#    'Sebastian Stan',
#    'Tommy Lee Jones']},
#  {'Title': 'Captain America: The Winter Soldier',
#   'Director': ['Anthony Russo', 'Joe Russo'],
#   'Writer': ['Christopher Markus',
#    'Stephen McFeely',
#    'Joe Simon',
#    'Jack Kirby'],
#   'Actors': ['Chris Evans',
#    'Samuel L. Jackson',
#    'Scarlett Johansson',
#    'Robert Redford']},
#  {'Title': "Captain Corelli's Mandolin",
#   'Director': ['John Madden'],
#   'Writer': ['Shawn Slovo', 'Louis de Bernières'],
#   'Actors': ['Penélope Cruz', 'John Hurt', 'Christian Bale', 'Irene Papas']},
#  {'Title': 'Captain Marvel',
#   'Director': ['Anna Boden', 'Ryan Fleck'],
#   'Writer': ['Anna Boden',
#    'Ryan Fleck',
#    'Geneva Robertson-Dworet',
#    'Nicole Perlman',
#    'Meg LeFauve',
#    'Anna Boden',
#    'Ryan Fleck',
#    'Geneva Robertson-Dworet'],
#   'Actors': ['Brie Larson',
#    'Samuel L. Jackson',
#    'Ben Mendelsohn',
#    'Jude Law']},
#  {'Title': 'Captain Phillips',
#   'Director': ['Paul Greengrass'],
#   'Writer': ['Billy Ray',
#    'Richard Phillips',
#    'Navy SEALS',
#    'and Dangerous Days at Sea" by)',
#    'Stephan Talty',
#    'Navy SEALS',
#    'and Dangerous Days at Sea" by)'],
#   'Actors': ['Tom Hanks',
#    'Catherine Keener',
#    'Barkhad Abdi',
#    'Barkhad Abdirahman']},
#  {'Title': 'Cars',
#   'Director': ['John Lasseter', 'Joe Ranft(co-director)'],
#   'Writer': ['John Lasseter',
#    'Joe Ranft',
#    'Jorgen Klubien',
#    'Dan Fogelman',
#    'John Lasseter',
#    'Joe Ranft',
#    'Kiel Murray',
#    'Phil Lorin',
#    'Jorgen Klubien',
#    'Steve Purcell'],
#   'Actors': ['Owen Wilson',
#    'Paul Newman',
#    'Bonnie Hunt',
#    'Larry the Cable Guy']},
#  {'Title': 'Cars 3',
#   'Director': ['Brian Fee'],
#   'Writer': ['Brian Fee',
#    'Ben Queen',
#    'Eyal Podell',
#    'Jonathon E. Stewart',
#    'Kiel Murray',
#    'Bob Peterson',
#    'Mike Rich',
#    'Scott Morse'],
#   'Actors': ['Owen Wilson',
#    'Cristela Alonzo',
#    'Chris Cooper',
#    'Nathan Fillion']},
#  {'Title': 'Casino Royale',
#   'Director': ['Martin Campbell'],
#   'Writer': ['Neal Purvis', 'Robert Wade', 'Paul Haggis', 'Ian Fleming'],
#   'Actors': ['Daniel Craig', 'Eva Green', 'Mads Mikkelsen', 'Judi Dench']},
#  {'Title': 'Cast Away',
#   'Director': ['Robert Zemeckis'],
#   'Writer': ['William Broyles Jr.'],
#   'Actors': ['Paul Sanchez',
#    'Lari White',
#    'Leonid Citer',
#    'David Allen Brooks']},
#  {'Title': 'Cats',
#   'Director': ['David Mallet'],
#   'Writer': ['T.S. Eliot'],
#   'Actors': ['Elaine Paige', 'John Mills', 'Ken Page', 'Rosemarie Ford']},
#  {'Title': 'Cats',
#   'Director': ['David Mallet'],
#   'Writer': ['T.S. Eliot'],
#   'Actors': ['Elaine Paige', 'John Mills', 'Ken Page', 'Rosemarie Ford']},
#  {'Title': 'Catwoman',
#   'Director': ['Pitof'],
#   'Writer': ['Bob Kane',
#    'Theresa Rebeck',
#    'John Brancato',
#    'Michael Ferris',
#    'John Brancato',
#    'Michael Ferris',
#    'John Rogers'],
#   'Actors': ['Halle Berry',
#    'Benjamin Bratt',
#    'Sharon Stone',
#    'Lambert Wilson']},
#  {'Title': 'Charlie and the Chocolate Factory',
#   'Director': ['Tim Burton'],
#   'Writer': ['Roald Dahl', 'John August'],
#   'Actors': ['Johnny Depp',
#    'Freddie Highmore',
#    'David Kelly',
#    'Helena Bonham Carter']},
#  {'Title': "Charlie Wilson's War",
#   'Director': ['Mike Nichols'],
#   'Writer': ['Aaron Sorkin', 'George Crile'],
#   'Actors': ['Tom Hanks',
#    'Amy Adams',
#    'Julia Roberts',
#    'Philip Seymour Hoffman']},
#  {'Title': "Charlie's Angels",
#   'Director': ['McG'],
#   'Writer': ['Ryan Rowe',
#    'Ed Solomon',
#    'John August',
#    'Ivan Goff',
#    'Ben Roberts'],
#   'Actors': ['Cameron Diaz', 'Drew Barrymore', 'Lucy Liu', 'Bill Murray']},
#  {'Title': "Charlie's Angels: Full Throttle",
#   'Director': ['McG'],
#   'Writer': ['Ivan Goff',
#    'Ben Roberts',
#    'John August',
#    'John August',
#    'Cormac Wibberley',
#    'Marianne Wibberley'],
#   'Actors': ['Cameron Diaz', 'Drew Barrymore', 'Lucy Liu', 'Bernie Mac']},
#  {'Title': "Charlotte's Web",
#   'Director': ['Gary Winick'],
#   'Writer': ['Susannah Grant',
#    'Karey Kirkpatrick',
#    'Earl Hamner Jr.',
#    'E.B. White'],
#   'Actors': ['Julia Roberts',
#    'Steve Buscemi',
#    'John Cleese',
#    'Oprah Winfrey']},
#  {'Title': 'Cheaper by the Dozen 2',
#   'Director': ['Adam Shankman'],
#   'Writer': ['Sam Harper',
#    'Craig Titley',
#    'Frank B. Gilbreth Jr.',
#    'Ernestine Gilbreth Carey'],
#   'Actors': ['Steve Martin', 'Eugene Levy', 'Bonnie Hunt', 'Tom Welling']},
#  {'Title': 'Chicken Little',
#   'Director': ['Mark Dindal'],
#   'Writer': ['Mark Dindal',
#    'Mark Kennedy',
#    'Steve Bencich',
#    'Ron J. Friedman',
#    'Ron Anderson',
#    'Robert L. Baird',
#    'Daniel Gerson',
#    'Sara Parriott',
#    'Josann McGibbon',
#    'David Reynolds',
#    'Sandra Tsing Loh'],
#   'Actors': ['Zach Braff', 'Garry Marshall', 'Don Knotts', 'Patrick Stewart']},
#  {'Title': 'Children of Men',
#   'Director': ['Alfonso Cuarón'],
#   'Writer': ['Alfonso Cuarón',
#    'Timothy J. Sexton',
#    'David Arata',
#    'Mark Fergus',
#    'Hawk Ostby',
#    'P.D. James'],
#   'Actors': ['Clive Owen',
#    'Juan Gabriel Yacuzzi',
#    'Michael Caine',
#    'Mishal Husain']},
#  {'Title': 'Christopher Robin',
#   'Director': ['Marc Forster'],
#   'Writer': ['A.A. Milne',
#    'Ernest Shepard',
#    'Alex Ross Perry',
#    'Tom McCarthy',
#    'Allison Schroeder',
#    'Greg Brooker',
#    'Mark Steven Johnson'],
#   'Actors': ['Ewan McGregor',
#    'Hayley Atwell',
#    'Bronte Carmichael',
#    'Mark Gatiss']},
#  {'Title': 'Cinderella',
#   'Director': ['Kenneth Branagh'],
#   'Writer': ['Chris Weitz', 'Charles Perrault'],
#   'Actors': ['Cate Blanchett',
#    'Lily James',
#    'Richard Madden',
#    'Helena Bonham Carter']},
#  {'Title': 'Cinderella Man',
#   'Director': ['Ron Howard'],
#   'Writer': ['Cliff Hollingsworth', 'Akiva Goldsman', 'Cliff Hollingsworth'],
#   'Actors': ['Russell Crowe',
#    'Renée Zellweger',
#    'Paul Giamatti',
#    'Craig Bierko']},
#  {'Title': 'Clash of the Titans',
#   'Director': ['Louis Leterrier'],
#   'Writer': ['Travis Beacham', 'Phil Hay', 'Matt Manfredi', 'Beverley Cross'],
#   'Actors': ['Sam Worthington',
#    'Liam Neeson',
#    'Ralph Fiennes',
#    'Jason Flemyng']},
#  {'Title': 'Clear and Present Danger',
#   'Director': ['Phillip Noyce'],
#   'Writer': ['Tom Clancy',
#    'Donald E. Stewart',
#    'Steven Zaillian',
#    'John Milius'],
#   'Actors': ['Harrison Ford',
#    'Willem Dafoe',
#    'Anne Archer',
#    'Joaquim de Almeida']},
#  {'Title': 'Click',
#   'Director': ['Frank Coraci'],
#   'Writer': ['Steve Koren', "Mark O'Keefe"],
#   'Actors': ['Adam Sandler',
#    'Kate Beckinsale',
#    'Christopher Walken',
#    'David Hasselhoff']},
#  {'Title': 'Cloud Atlas',
#   'Director': ['Tom Tykwer', 'Lana Wachowski', 'Lilly Wachowski'],
#   'Writer': ['David Mitchell',
#    'Lana Wachowski',
#    'Tom Tykwer',
#    'Lilly Wachowski',
#    'Chris Lindsay'],
#   'Actors': ['Tom Hanks', 'Halle Berry', 'Jim Broadbent', 'Hugo Weaving']},
#  {'Title': 'Cloudy with a Chance of Meatballs',
#   'Director': ['Phil Lord', 'Christopher Miller'],
#   'Writer': ['Phil Lord',
#    'Christopher Miller',
#    'Judi Barrett',
#    'Ron Barrett',
#    'Rob Greenberg'],
#   'Actors': ['Bill Hader', 'Anna Faris', 'James Caan', 'Andy Samberg']},
#  {'Title': 'Cloudy with a Chance of Meatballs 2',
#   'Director': ['Cody Cameron', 'Kris Pearn'],
#   'Writer': ['Erica Rivinoja',
#    'John Francis Daley',
#    'Jonathan Goldstein',
#    'Phil Lord',
#    'Christopher Miller',
#    'Erica Rivinoja',
#    'Judi Barrett',
#    'Ron Barrett'],
#   'Actors': ['Bill Hader', 'Anna Faris', 'James Caan', 'Will Forte']},
#  {'Title': 'Coco',
#   'Director': ['Lee Unkrich', 'Adrian Molina(co-director)'],
#   'Writer': ['Lee Unkrich',
#    'Jason Katz',
#    'Matthew Aldrich',
#    'Adrian Molina',
#    'Adrian Molina',
#    'Matthew Aldrich'],
#   'Actors': ['Anthony Gonzalez',
#    'Gael García Bernal',
#    'Benjamin Bratt',
#    'Alanna Ubach']},
#  {'Title': 'Cold Mountain',
#   'Director': ['Anthony Minghella'],
#   'Writer': ['Charles Frazier', 'Anthony Minghella'],
#   'Actors': ['Jude Law', 'Nicole Kidman', 'Renée Zellweger', 'Eileen Atkins']},
#  {'Title': 'Cold Pursuit',
#   'Director': ['Hans Petter Moland'],
#   'Writer': ['Frank Baldwin', 'Kim Fupz Aakeson'],
#   'Actors': ['Liam Neeson',
#    'Laura Dern',
#    'Micheál Richardson',
#    'Michael Eklund']},
#  {'Title': 'Collateral',
#   'Director': ['Michael Mann'],
#   'Writer': ['Stuart Beattie'],
#   'Actors': ['Tom Cruise',
#    'Jamie Foxx',
#    'Jada Pinkett Smith',
#    'Mark Ruffalo']},
#  {'Title': 'Con Air',
#   'Director': ['Simon West'],
#   'Writer': ['Scott Rosenberg'],
#   'Actors': ['Colm Meaney',
#    'Mykelti Williamson',
#    'Nick Chinlund',
#    'Renoly Santiago']},
#  {'Title': 'Conan the Barbarian',
#   'Director': ['John Milius'],
#   'Writer': ['Robert E. Howard', 'John Milius', 'Oliver Stone'],
#   'Actors': ['Arnold Schwarzenegger',
#    'James Earl Jones',
#    'Max von Sydow',
#    'Sandahl Bergman']},
#  {'Title': 'Constantine',
#   'Director': ['Francis Lawrence'],
#   'Writer': ['Jamie Delano',
#    'Garth Ennis',
#    'Kevin Brodbin',
#    'Kevin Brodbin',
#    'Frank A. Cappello'],
#   'Actors': ['Keanu Reeves',
#    'Rachel Weisz',
#    'Shia LaBeouf',
#    'Djimon Hounsou']},
#  {'Title': 'Contact',
#   'Director': ['Robert Zemeckis'],
#   'Writer': ['James V. Hart',
#    'Michael Goldenberg',
#    'Carl Sagan',
#    'Carl Sagan',
#    'Ann Druyan'],
#   'Actors': ['Jena Malone', 'David Morse', 'Jodie Foster', 'Geoffrey Blake']},
#  {'Title': 'Contagion',
#   'Director': ['Steven Soderbergh'],
#   'Writer': ['Scott Z. Burns'],
#   'Actors': ['Gwyneth Paltrow',
#    'Tien You Chui',
#    'Josie Ho',
#    'Daria Strokous']},
#  {'Title': 'Coraline',
#   'Director': ['Henry Selick'],
#   'Writer': ['Henry Selick', 'Neil Gaiman'],
#   'Actors': ['Dakota Fanning',
#    'Teri Hatcher',
#    'Jennifer Saunders',
#    'Dawn French']},
#  {'Title': 'Couples Retreat',
#   'Director': ['Peter Billingsley'],
#   'Writer': ['Jon Favreau', 'Vince Vaughn', 'Dana Fox'],
#   'Actors': ['Vince Vaughn', 'Jason Bateman', 'Faizon Love', 'Jon Favreau']},
#  {'Title': 'Daddy Day Care',
#   'Director': ['Steve Carr'],
#   'Writer': ['Geoff Rodkey'],
#   'Actors': ['Eddie Murphy', 'Jeff Garlin', 'Steve Zahn', 'Regina King']},
#  {'Title': 'Daredevil',
#   'Director': ['N/A'],
#   'Writer': ['Drew Goddard'],
#   'Actors': ['Charlie Cox',
#    'Deborah Ann Woll',
#    'Elden Henson',
#    "Vincent D'Onofrio"]},
#  {'Title': 'Dark Phoenix',
#   'Director': ['Simon Kinberg'],
#   'Writer': ['John Byrne',
#    'Chris Claremont',
#    'Dave Cockrum',
#    'Simon Kinberg',
#    'Jack Kirby',
#    'Stan Lee'],
#   'Actors': ['James McAvoy',
#    'Michael Fassbender',
#    'Jennifer Lawrence',
#    'Nicholas Hoult']},
#  {'Title': 'Dark Shadows',
#   'Director': ['Tim Burton'],
#   'Writer': ['Seth Grahame-Smith',
#    'John August',
#    'Seth Grahame-Smith',
#    'Dan Curtis'],
#   'Actors': ['Johnny Depp',
#    'Michelle Pfeiffer',
#    'Helena Bonham Carter',
#    'Eva Green']},
#  {'Title': 'Dark Water',
#   'Director': ['Walter Salles'],
#   'Writer': ['Kôji Suzuki',
#    'Hideo Nakata',
#    'Takashige Ichise',
#    'Rafael Yglesias'],
#   'Actors': ['Jennifer Connelly',
#    'John C. Reilly',
#    'Tim Roth',
#    'Dougray Scott']},
#  {'Title': 'Dawn of the Planet of the Apes',
#   'Director': ['Matt Reeves'],
#   'Writer': ['Mark Bomback',
#    'Rick Jaffa',
#    'Amanda Silver',
#    'Rick Jaffa',
#    'Amanda Silver'],
#   'Actors': ['Andy Serkis', 'Jason Clarke', 'Gary Oldman', 'Keri Russell']},
#  {'Title': 'Days of Thunder',
#   'Director': ['Tony Scott'],
#   'Writer': ['Robert Towne', 'Tom Cruise', 'Robert Towne'],
#   'Actors': ['Tom Cruise', 'Nicole Kidman', 'Robert Duvall', 'Randy Quaid']},
#  {'Title': 'Deadpool',
#   'Director': ['Tim Miller'],
#   'Writer': ['Rhett Reese', 'Paul Wernick'],
#   'Actors': ['Ryan Reynolds', 'Karan Soni', 'Ed Skrein', 'Michael Benyaer']},
#  {'Title': 'Deadpool 2',
#   'Director': ['David Leitch'],
#   'Writer': ['Rhett Reese', 'Paul Wernick', 'Ryan Reynolds'],
#   'Actors': ['Ryan Reynolds',
#    'Josh Brolin',
#    'Morena Baccarin',
#    'Julian Dennison']},
#  {'Title': 'Death Race',
#   'Director': ['Paul W.S. Anderson'],
#   'Writer': ['Paul W.S. Anderson',
#    'Paul W.S. Anderson',
#    'Robert Thom',
#    'Charles B. Griffith',
#    'Ib Melchior'],
#   'Actors': ['Jason Statham', 'Joan Allen', 'Ian McShane', 'Tyrese Gibson']},
#  {'Title': 'Deep Blue Sea',
#   'Director': ['Renny Harlin'],
#   'Writer': ['Duncan Kennedy', 'Donna Powers', 'Wayne Powers'],
#   'Actors': ['Thomas Jane',
#    'Saffron Burrows',
#    'Samuel L. Jackson',
#    'Jacqueline McKenzie']},
#  {'Title': 'Deep Impact',
#   'Director': ['Mimi Leder'],
#   'Writer': ['Bruce Joel Rubin', 'Michael Tolkin'],
#   'Actors': ['Robert Duvall', 'Téa Leoni', 'Elijah Wood', 'Vanessa Redgrave']},
#  {'Title': 'Deepwater Horizon',
#   'Director': ['Peter Berg'],
#   'Writer': ['Matthew Michael Carnahan',
#    'Matthew Sand',
#    'Matthew Sand',
#    'David Barstow',
#    'David Rohde',
#    'Stephanie Saul'],
#   'Actors': ['Mark Wahlberg',
#    'Kurt Russell',
#    'Douglas M. Griffin',
#    'James DuMont']},
#  {'Title': 'Despicable Me',
#   'Director': ['Pierre Coffin', 'Chris Renaud'],
#   'Writer': ['Cinco Paul', 'Ken Daurio', 'Sergio Pablos'],
#   'Actors': ['Steve Carell', 'Jason Segel', 'Russell Brand', 'Julie Andrews']},
#  {'Title': 'Despicable Me 2',
#   'Director': ['Pierre Coffin', 'Chris Renaud'],
#   'Writer': ['Cinco Paul', 'Ken Daurio'],
#   'Actors': ['Steve Carell',
#    'Kristen Wiig',
#    'Benjamin Bratt',
#    'Miranda Cosgrove']},
#  {'Title': 'Despicable Me 3',
#   'Director': ['Kyle Balda', 'Pierre Coffin', 'Eric Guillon(co-director)'],
#   'Writer': ['Cinco Paul', 'Ken Daurio'],
#   'Actors': ['Steve Carell',
#    'Kristen Wiig',
#    'Trey Parker',
#    'Miranda Cosgrove']},
#  {'Title': 'Did You Hear About the Morgans?',
#   'Director': ['Marc Lawrence'],
#   'Writer': ['Marc Lawrence'],
#   'Actors': ['Hugh Grant',
#    'Sarah Jessica Parker',
#    'Natalia Klimas',
#    'Vincenzo Amato']},
#  {'Title': 'Die Another Day',
#   'Director': ['Lee Tamahori'],
#   'Writer': ['Ian Fleming', 'Neal Purvis', 'Robert Wade'],
#   'Actors': ['Pierce Brosnan',
#    'Halle Berry',
#    'Toby Stephens',
#    'Rosamund Pike']},
#  {'Title': 'Die Hard 2',
#   'Director': ['Renny Harlin'],
#   'Writer': ['Walter Wager', 'Steven E. de Souza', 'Doug Richardson'],
#   'Actors': ['Bruce Willis',
#    'Bonnie Bedelia',
#    'William Atherton',
#    'Reginald VelJohnson']},
#  {'Title': 'Die Hard with a Vengeance',
#   'Director': ['John McTiernan'],
#   'Writer': ['Jonathan Hensleigh', 'Roderick Thorp'],
#   'Actors': ['Bruce Willis',
#    'Jeremy Irons',
#    'Samuel L. Jackson',
#    'Graham Greene']},
#  {'Title': 'Dinner for Schmucks',
#   'Director': ['Jay Roach'],
#   'Writer': ['David Guion', 'Michael Handelman', 'Francis Veber'],
#   'Actors': ['Steve Carell',
#    'Paul Rudd',
#    'Zach Galifianakis',
#    'Jemaine Clement']},
#  {'Title': 'Dinosaur',
#   'Director': ['Eric Leighton', 'Ralph Zondag'],
#   'Writer': ['Thom Enriquez',
#    'John Harrison',
#    'Robert Nelson Jacobs',
#    'Ralph Zondag',
#    'John Harrison',
#    'Robert Nelson Jacobs',
#    'Walon Green',
#    'Gregory Gunter',
#    'Shirley Pierce',
#    'Jonathan Roberts',
#    'Rhett Reese',
#    'Tamara Lusher Stocker'],
#   'Actors': ['Alfre Woodard',
#    'Ossie Davis',
#    'Max Casella',
#    'Hayden Panettiere']},
#  {'Title': 'Divergent',
#   'Director': ['Neil Burger'],
#   'Writer': ['Evan Daugherty', 'Vanessa Taylor', 'Veronica Roth'],
#   'Actors': ['Shailene Woodley', 'Theo James', 'Ashley Judd', 'Jai Courtney']},
#  {'Title': 'Django Unchained',
#   'Director': ['Quentin Tarantino'],
#   'Writer': ['Quentin Tarantino'],
#   'Actors': ['Jamie Foxx',
#    'Christoph Waltz',
#    'Leonardo DiCaprio',
#    'Kerry Washington']},
#  {'Title': 'Doctor Dolittle',
#   'Director': ['Betty Thomas'],
#   'Writer': ['Hugh Lofting', 'Nat Mauldin', 'Larry Levin'],
#   'Actors': ['Eddie Murphy', 'Ossie Davis', 'Oliver Platt', 'Peter Boyle']},
#  {'Title': 'Doctor Strange',
#   'Director': ['Scott Derrickson'],
#   'Writer': ['Jon Spaihts',
#    'Scott Derrickson',
#    'C. Robert Cargill',
#    'Stan Lee',
#    'Steve Ditko'],
#   'Actors': ['Benedict Cumberbatch',
#    'Chiwetel Ejiofor',
#    'Rachel McAdams',
#    'Benedict Wong']},
#  {'Title': 'Downsizing',
#   'Director': ['Alexander Payne'],
#   'Writer': ['Alexander Payne', 'Jim Taylor'],
#   'Actors': ['Matt Damon', 'Christoph Waltz', 'Hong Chau', 'Kristen Wiig']},
#  {'Title': 'Dr. Dolittle 2',
#   'Director': ['Steve Carr'],
#   'Writer': ['Hugh Lofting', 'Larry Levin'],
#   'Actors': ['Eddie Murphy', 'Kristen Wilson', 'Raven-Symoné', 'Kyla Pratt']},
#  {'Title': 'Dracula Untold',
#   'Director': ['Gary Shore'],
#   'Writer': ['Matt Sazama', 'Burk Sharpless', 'Bram Stoker'],
#   'Actors': ['Luke Evans', 'Sarah Gadon', 'Dominic Cooper', 'Art Parkinson']},
#  {'Title': 'Dreamcatcher',
#   'Director': ['Lawrence Kasdan'],
#   'Writer': ['Stephen King', 'William Goldman', 'Lawrence Kasdan'],
#   'Actors': ['Morgan Freeman', 'Thomas Jane', 'Jason Lee', 'Damian Lewis']},
#  {'Title': 'Dreamgirls',
#   'Director': ['Bill Condon'],
#   'Writer': ['Tom Eyen', 'Bill Condon'],
#   'Actors': ['Jamie Foxx', 'Beyoncé', 'Eddie Murphy', 'Danny Glover']},
#  {'Title': 'Driven',
#   'Director': ['Renny Harlin'],
#   'Writer': ['Jan Skrentny', 'Neal Tabachnick', 'Sylvester Stallone'],
#   'Actors': ['Sylvester Stallone',
#    'Burt Reynolds',
#    'Kip Pardue',
#    'Stacy Edwards']},
#  {'Title': 'Due Date',
#   'Director': ['Todd Phillips'],
#   'Writer': ['Alan R. Cohen',
#    'Alan Freedland',
#    'Adam Sztykiel',
#    'Todd Phillips',
#    'Alan R. Cohen',
#    'Alan Freedland'],
#   'Actors': ['Robert Downey Jr.',
#    'Zach Galifianakis',
#    'Michelle Monaghan',
#    'Jamie Foxx']},
#  {'Title': 'Dumbo',
#   'Director': ['Samuel Armstrong',
#    'Norman Ferguson',
#    'Wilfred Jackson',
#    'Jack Kinney',
#    'Bill Roberts',
#    'Ben Sharpsteen',
#    'John Elliotte'],
#   'Writer': ['Joe Grant',
#    'Dick Huemer',
#    'Otto Englander',
#    'Bill Peet',
#    'Aurelius Battaglia',
#    'Joe Rinaldi',
#    'Vernon Stallings',
#    'Webb Smith'],
#   'Actors': ['James Baskett', 'Herman Bing', 'Mel Blanc', 'Billy Bletcher']},
#  {'Title': 'Dunkirk',
#   'Director': ['Christopher Nolan'],
#   'Writer': ['Christopher Nolan'],
#   'Actors': ['Fionn Whitehead',
#    'Damien Bonnard',
#    'Aneurin Barnard',
#    'Lee Armstrong']},
#  {'Title': 'Duplicity',
#   'Director': ['Tony Gilroy'],
#   'Writer': ['Tony Gilroy'],
#   'Actors': ['Clive Owen', 'Julia Roberts', 'Tom Wilkinson', 'Paul Giamatti']},
#  {'Title': 'Eagle Eye',
#   'Director': ['D.J. Caruso'],
#   'Writer': ['John Glenn',
#    'Travis Wright',
#    'Hillary Seitz',
#    'Dan McDermott',
#    'Dan McDermott'],
#   'Actors': ['Shia LaBeouf',
#    'Michelle Monaghan',
#    'Rosario Dawson',
#    'Michael Chiklis']},
#  {'Title': 'Eat Pray Love',
#   'Director': ['Ryan Murphy'],
#   'Writer': ['Ryan Murphy', 'Jennifer Salt', 'Elizabeth Gilbert'],
#   'Actors': ['Julia Roberts',
#    'I. Gusti Ayu Puspawati',
#    'Hadi Subiyanto',
#    'Billy Crudup']},
#  {'Title': 'Edge of Darkness',
#   'Director': ['Martin Campbell'],
#   'Writer': ['William Monahan', 'Andrew Bovell', 'Troy Kennedy-Martin'],
#   'Actors': ['Mel Gibson',
#    'Ray Winstone',
#    'Danny Huston',
#    'Bojana Novakovic']},
#  {'Title': 'Edge of Tomorrow',
#   'Director': ['Doug Liman'],
#   'Writer': ['Christopher McQuarrie',
#    'Jez Butterworth',
#    'John-Henry Butterworth',
#    'Hiroshi Sakurazaka'],
#   'Actors': ['Tom Cruise', 'Emily Blunt', 'Brendan Gleeson', 'Bill Paxton']},
#  {'Title': 'Edtv',
#   'Director': ['Ron Howard'],
#   'Writer': ['Émile Gaudreault',
#    'le roi des ondes")',
#    'Sylvie Bouchard',
#    'le roi des ondes")',
#    'Lowell Ganz',
#    'Babaloo Mandel'],
#   'Actors': ['Geoffrey Blake', 'Gail Boggs', 'Jenna Byrne', 'Merrin Dungey']},
#  {'Title': 'Elektra',
#   'Director': ['Rob Bowman'],
#   'Writer': ['Mark Steven Johnson',
#    'Frank Miller',
#    'Zak Penn',
#    'Stuart Zicherman',
#    'M. Raven Metzner'],
#   'Actors': ['Jennifer Garner',
#    'Goran Visnjic',
#    'Kirsten Zien',
#    'Will Yun Lee']},
#  {'Title': 'Elysium',
#   'Director': ['Neill Blomkamp'],
#   'Writer': ['Neill Blomkamp'],
#   'Actors': ['Matt Damon', 'Jodie Foster', 'Sharlto Copley', 'Alice Braga']},
#  {'Title': 'Enchanted',
#   'Director': ['Kevin Lima'],
#   'Writer': ['Bill Kelly'],
#   'Actors': ['Amy Adams',
#    'Patrick Dempsey',
#    'James Marsden',
#    'Timothy Spall']},
#  {'Title': "Ender's Game",
#   'Director': ['Gavin Hood'],
#   'Writer': ['Gavin Hood', 'Orson Scott Card'],
#   'Actors': ['Asa Butterfield',
#    'Harrison Ford',
#    'Hailee Steinfeld',
#    'Abigail Breslin']},
#  {'Title': 'Enemy at the Gates',
#   'Director': ['Jean-Jacques Annaud'],
#   'Writer': ['Jean-Jacques Annaud', 'Alain Godard'],
#   'Actors': ['Jude Law', 'Ed Harris', 'Rachel Weisz', 'Joseph Fiennes']},
#  {'Title': 'Enemy of the State',
#   'Director': ['Tony Scott'],
#   'Writer': ['David Marconi'],
#   'Actors': ['Will Smith', 'Gene Hackman', 'Jon Voight', 'Lisa Bonet']},
#  {'Title': 'Epic',
#   'Director': ['Chris Wedge'],
#   'Writer': ['James V. Hart',
#    'William Joyce',
#    'Daniel Shere',
#    'Tom J. Astle',
#    'Matt Ember',
#    'William Joyce',
#    'James V. Hart',
#    'Chris Wedge',
#    'William Joyce'],
#   'Actors': ['Blake Anderson', 'Aziz Ansari', 'Allison Bills', 'Jim Conroy']},
#  {'Title': 'Eraser',
#   'Director': ['Chuck Russell'],
#   'Writer': ['Tony Puryear',
#    'Walon Green',
#    'Michael S. Chernuchin',
#    'Tony Puryear',
#    'Walon Green'],
#   'Actors': ['Arnold Schwarzenegger',
#    'James Caan',
#    'Vanessa Williams',
#    'James Coburn']},
#  {'Title': 'Escape Plan',
#   'Director': ['Mikael Håfström'],
#   'Writer': ['Miles Chapman', 'Jason Keller', 'Miles Chapman'],
#   'Actors': ['Sylvester Stallone',
#    'Arnold Schwarzenegger',
#    'Jim Caviezel',
#    'Faran Tahir']},
#  {'Title': 'Evan Almighty',
#   'Director': ['Tom Shadyac'],
#   'Writer': ['Steve Oedekerk',
#    'Steve Oedekerk',
#    'Joel Cohen',
#    'Alec Sokolow',
#    'Steve Koren',
#    "Mark O'Keefe"],
#   'Actors': ['Steve Carell',
#    'Morgan Freeman',
#    'Lauren Graham',
#    'Johnny Simmons']},
#  {'Title': 'Everest',
#   'Director': ['Baltasar Kormákur'],
#   'Writer': ['William Nicholson', 'Simon Beaufoy'],
#   'Actors': ['Jason Clarke',
#    'Ang Phula Sherpa',
#    'Thomas M. Wright',
#    'Martin Henderson']},
#  {'Title': 'Evolution',
#   'Director': ['Ivan Reitman'],
#   'Writer': ['Don Jakoby', 'David Diamond', 'David Weissman', 'Don Jakoby'],
#   'Actors': ['David Duchovny',
#    'Julianne Moore',
#    'Orlando Jones',
#    'Seann William Scott']},
#  {'Title': 'Exodus: Gods and Kings',
#   'Director': ['Ridley Scott'],
#   'Writer': ['Adam Cooper',
#    'Bill Collage',
#    'Jeffrey Caine',
#    'Steven Zaillian'],
#   'Actors': ['Christian Bale',
#    'Joel Edgerton',
#    'John Turturro',
#    'Aaron Paul']},
#  {'Title': 'Exorcist: The Beginning',
#   'Director': ['Renny Harlin'],
#   'Writer': ['William Peter Blatty',
#    'William Wisher',
#    'Caleb Carr',
#    'Alexi Hawley'],
#   'Actors': ['Stellan Skarsgård',
#    'Izabella Scorupco',
#    "James D'Arcy",
#    'Remy Sweeney']},
#  {'Title': 'Face/Off',
#   'Director': ['John Woo'],
#   'Writer': ['Mike Werb', 'Michael Colleary'],
#   'Actors': ['John Travolta',
#    'Nicolas Cage',
#    'Joan Allen',
#    'Alessandro Nivola']},
#  {'Title': 'Fantastic Beasts and Where to Find Them',
#   'Director': ['David Yates'],
#   'Writer': ['J.K. Rowling'],
#   'Actors': ['Eddie Redmayne',
#    'Sam Redford',
#    'Scott Goldman',
#    'Tim Bentinck']},
#  {'Title': 'Fantastic Beasts: The Crimes of Grindelwald',
#   'Director': ['David Yates'],
#   'Writer': ['J.K. Rowling', 'J.K. Rowling'],
#   'Actors': ['Johnny Depp', 'Kevin Guthrie', 'Carmen Ejogo', 'Wolf Roth']},
#  {'Title': 'Fantastic Four',
#   'Director': ['Tim Story'],
#   'Writer': ['Mark Frost', 'Michael France', 'Stan Lee', 'Jack Kirby'],
#   'Actors': ['Ioan Gruffudd',
#    'Jessica Alba',
#    'Chris Evans',
#    'Michael Chiklis']},
#  {'Title': 'Fast & Furious 6',
#   'Director': ['Justin Lin'],
#   'Writer': ['Chris Morgan', 'Gary Scott Thompson'],
#   'Actors': ['Vin Diesel',
#    'Paul Walker',
#    'Dwayne Johnson',
#    'Jordana Brewster']},
#  {'Title': 'Fast Five',
#   'Director': ['Justin Lin'],
#   'Writer': ['Chris Morgan', 'Gary Scott Thompson'],
#   'Actors': ['Vin Diesel',
#    'Paul Walker',
#    'Jordana Brewster',
#    'Tyrese Gibson']},
#  {'Title': 'Ferdinand',
#   'Director': ['Carlos Saldanha'],
#   'Writer': ['Robert L. Baird',
#    'Tim Federle',
#    'Brad Copeland',
#    'Ron Burch',
#    'David Kidd',
#    'Don Rhymer',
#    'Munro Leaf',
#    'Robert Lawson'],
#   'Actors': ['Jack Gore', 'Jet Jurgensmeyer', 'Nile Diaz', 'Colin H. Murphy']},
#  {'Title': 'Fifty Shades Darker',
#   'Director': ['James Foley'],
#   'Writer': ['Niall Leonard', 'E.L. James'],
#   'Actors': ['Dakota Johnson',
#    'Jamie Dornan',
#    'Eric Johnson',
#    'Eloise Mumford']},
#  {'Title': 'Fight Club',
#   'Director': ['David Fincher'],
#   'Writer': ['Chuck Palahniuk', 'Jim Uhls'],
#   'Actors': ['Edward Norton', 'Brad Pitt', 'Meat Loaf', 'Zach Grenier']},
#  {'Title': 'Final Fantasy: The Spirits Within',
#   'Director': ['Hironobu Sakaguchi', 'Motonori Sakakibara(co-director)'],
#   'Writer': ['Hironobu Sakaguchi',
#    'Al Reinert',
#    'Jeff Vintar',
#    'Jack Fletcher',
#    'Bruce B.L. Jurgens',
#    'Ramin Mebdy'],
#   'Actors': ['Ming-Na Wen', 'Alec Baldwin', 'Ving Rhames', 'Steve Buscemi']},
#  {'Title': 'Finding Dory',
#   'Director': ['Andrew Stanton', 'Angus MacLane(co-director)'],
#   'Writer': ['Andrew Stanton',
#    'Andrew Stanton',
#    'Victoria Strouse',
#    'Bob Peterson',
#    'Angus MacLane'],
#   'Actors': ['Ellen DeGeneres',
#    'Albert Brooks',
#    "Ed O'Neill",
# ...
#    'Rosie Huntington-Whiteley',
#    'Josh Duhamel',
#    'John Turturro']},
#  {'Title': 'Transformers: Revenge of the Fallen',
#   'Director': ['Michael Bay'],
#   'Writer': ['Ehren Kruger', 'Roberto Orci', 'Alex Kurtzman'],
#   'Actors': ['Shia LaBeouf', 'Megan Fox', 'Josh Duhamel', 'Tyrese Gibson']},
#  {'Title': 'Transformers: The Last Knight',
#   'Director': ['Michael Bay'],
#   'Writer': ['Art Marcum',
#    'Matt Holloway',
#    'Ken Nolan',
#    'Akiva Goldsman',
#    'Art Marcum',
#    'Matt Holloway',
#    'Ken Nolan'],
#   'Actors': ['Mark Wahlberg',
#    'Anthony Hopkins',
#    'Josh Duhamel',
#    'Laura Haddock']},
#  {'Title': 'Treasure Planet',
#   'Director': ['Ron Clements', 'John Musker'],
#   'Writer': ['Robert Louis Stevenson',
#    'Ron Clements',
#    'John Musker',
#    'Rob Edwards',
#    'Ron Clements',
#    'John Musker',
#    'Ted Elliott',
#    'Terry Rossio'],
#   'Actors': ['Roscoe Lee Browne',
#    'Corey Burton',
#    'Dane A. Davis',
#    'Joseph Gordon-Levitt']},
#  {'Title': 'Trolls',
#   'Director': ['Mike Mitchell', 'Walt Dohrn(co-director)'],
#   'Writer': ['Jonathan Aibel', 'Glenn Berger', 'Erica Rivinoja', 'Thomas Dam'],
#   'Actors': ['Anna Kendrick',
#    'Justin Timberlake',
#    'Zooey Deschanel',
#    'Christopher Mintz-Plasse']},
#  {'Title': 'TRON: Legacy',
#   'Director': ['Joseph Kosinski'],
#   'Writer': ['Edward Kitsis',
#    'Adam Horowitz',
#    'Edward Kitsis',
#    'Adam Horowitz',
#    'Brian Klugman',
#    'Lee Sternthal',
#    'Steven Lisberger',
#    'Bonnie MacBird'],
#   'Actors': ['Jeff Bridges',
#    'Garrett Hedlund',
#    'Olivia Wilde',
#    'Bruce Boxleitner']},
#  {'Title': 'Tropic Thunder',
#   'Director': ['Ben Stiller'],
#   'Writer': ['Justin Theroux',
#    'Ben Stiller',
#    'Etan Cohen',
#    'Ben Stiller',
#    'Justin Theroux'],
#   'Actors': ['Jeff Kahn',
#    'Robert Downey Jr.',
#    'Anthony Ruivivar',
#    'Jack Black']},
#  {'Title': 'Trouble with the Curve',
#   'Director': ['Robert Lorenz'],
#   'Writer': ['Randy Brown'],
#   'Actors': ['Clint Eastwood',
#    'Chelcie Ross',
#    'Raymond Anthony Thomas',
#    'Ed Lauter']},
#  {'Title': 'Troy',
#   'Director': ['Wolfgang Petersen'],
#   'Writer': ['Homer', 'David Benioff'],
#   'Actors': ['Julian Glover', 'Brian Cox', 'Nathan Jones', 'Adoni Maropis']},
#  {'Title': 'True Lies',
#   'Director': ['James Cameron'],
#   'Writer': ['Claude Zidi',
#    'Simon Michaël',
#    'Didier Kaminka',
#    'James Cameron'],
#   'Actors': ['Arnold Schwarzenegger',
#    'Jamie Lee Curtis',
#    'Tom Arnold',
#    'Bill Paxton']},
#  {'Title': 'Turbo',
#   'Director': ['David Soren'],
#   'Writer': ['Darren Lemke', 'Robert Siegel', 'David Soren', 'David Soren'],
#   'Actors': ['Ryan Reynolds',
#    'Paul Giamatti',
#    'Michael Peña',
#    'Samuel L. Jackson']},
#  {'Title': 'Twister',
#   'Director': ['Jan de Bont'],
#   'Writer': ['Michael Crichton', 'Anne-Marie Martin'],
#   'Actors': ['Helen Hunt', 'Bill Paxton', 'Cary Elwes', 'Jami Gertz']},
#  {'Title': 'Two Brothers',
#   'Director': ['Jean-Jacques Annaud'],
#   'Writer': ['Alain Godard',
#    'Jean-Jacques Annaud',
#    'Jean-Jacques Annaud',
#    'Julian Fellowes'],
#   'Actors': ['Guy Pearce',
#    'Jean-Claude Dreyfus',
#    'Freddie Highmore',
#    'Oanh Nguyen']},
#  {'Title': 'Two Weeks Notice',
#   'Director': ['Marc Lawrence'],
#   'Writer': ['Marc Lawrence'],
#   'Actors': ['Sandra Bullock', 'Hugh Grant', 'Alicia Witt', 'Dana Ivey']},
#  {'Title': 'U-571',
#   'Director': ['Jonathan Mostow'],
#   'Writer': ['Jonathan Mostow',
#    'Jonathan Mostow',
#    'Sam Montgomery',
#    'David Ayer'],
#   'Actors': ['Matthew McConaughey',
#    'Bill Paxton',
#    'Harvey Keitel',
#    'Jon Bon Jovi']},
#  {'Title': 'Unbreakable',
#   'Director': ['M. Night Shyamalan'],
#   'Writer': ['M. Night Shyamalan'],
#   'Actors': ['Bruce Willis',
#    'Samuel L. Jackson',
#    'Robin Wright',
#    'Spencer Treat Clark']},
#  {'Title': 'Unbroken',
#   'Director': ['Angelina Jolie'],
#   'Writer': ['Joel Coen',
#    'Ethan Coen',
#    'Richard LaGravenese',
#    'William Nicholson',
#    'Laura Hillenbrand'],
#   'Actors': ["Jack O'Connell",
#    'Domhnall Gleeson',
#    'Garrett Hedlund',
#    'Miyavi']},
#  {'Title': 'Underworld Awakening',
#   'Director': ['Måns Mårlind', 'Björn Stein'],
#   'Writer': ['Len Wiseman',
#    'John Hlavin',
#    'J. Michael Straczynski',
#    'Allison Burnett',
#    'Len Wiseman',
#    'John Hlavin',
#    'Kevin Grevioux',
#    'Len Wiseman',
#    'Danny McBride'],
#   'Actors': ['Kate Beckinsale', 'Stephen Rea', 'Michael Ealy', 'Theo James']},
#  {'Title': 'Unstoppable',
#   'Director': ['Tony Scott'],
#   'Writer': ['Mark Bomback'],
#   'Actors': ['Denzel Washington',
#    'Chris Pine',
#    'Rosario Dawson',
#    'Ethan Suplee']},
#  {'Title': 'Up',
#   'Director': ['Pete Docter', 'Bob Peterson(co-director)'],
#   'Writer': ['Pete Docter',
#    'Bob Peterson',
#    'Tom McCarthy',
#    'Bob Peterson',
#    'Pete Docter'],
#   'Actors': ['Edward Asner',
#    'Christopher Plummer',
#    'Jordan Nagai',
#    'Bob Peterson']},
#  {'Title': 'Up Close',
#   'Director': ['N/A'],
#   'Writer': ['N/A'],
#   'Actors': ['David Sheehan',
#    'Woody Allen',
#    'Diane Keaton',
#    'Olivia Newton-John']},
#  {'Title': 'Valerian and the City of a Thousand Planets',
#   'Director': ['Luc Besson'],
#   'Writer': ['Pierre Christin', 'Jean-Claude Mézières', 'Luc Besson'],
#   'Actors': ['Dane DeHaan', 'Cara Delevingne', 'Clive Owen', 'Rihanna']},
#  {'Title': 'Valkyrie',
#   'Director': ['Bryan Singer'],
#   'Writer': ['Christopher McQuarrie', 'Nathan Alexander'],
#   'Actors': ['Tom Cruise', 'Kenneth Branagh', 'Bill Nighy', 'Tom Wilkinson']},
#  {'Title': 'Van Helsing',
#   'Director': ['Stephen Sommers'],
#   'Writer': ['Stephen Sommers'],
#   'Actors': ['Hugh Jackman',
#    'Kate Beckinsale',
#    'Richard Roxburgh',
#    'David Wenham']},
#  {'Title': 'Vanilla Sky',
#   'Director': ['Cameron Crowe'],
#   'Writer': ['Alejandro Amenábar', 'Mateo Gil', 'Cameron Crowe'],
#   'Actors': ['Tom Cruise', 'Penélope Cruz', 'Cameron Diaz', 'Kurt Russell']},
#  {'Title': 'Venom',
#   'Director': ['Ruben Fleischer'],
#   'Writer': ['Jeff Pinkner',
#    'Scott Rosenberg',
#    'Kelly Marcel',
#    'Jeff Pinkner',
#    'Scott Rosenberg',
#    'Todd McFarlane',
#    'David Michelinie'],
#   'Actors': ['Tom Hardy', 'Michelle Williams', 'Riz Ahmed', 'Scott Haze']},
#  {'Title': 'Vice',
#   'Director': ['Adam McKay'],
#   'Writer': ['Adam McKay'],
#   'Actors': ['Christian Bale', 'Amy Adams', 'Steve Carell', 'Sam Rockwell']},
#  {'Title': 'Walking Tall',
#   'Director': ['Kevin Bray'],
#   'Writer': ['Mort Briskin',
#    'David Klass',
#    'Channing Gibson',
#    'David Levien',
#    'Brian Koppelman'],
#   'Actors': ['Michael Bowen',
#    'Johnny Knoxville',
#    'Dwayne Johnson',
#    'Neal McDonough']},
#  {'Title': 'Walking with Dinosaurs',
#   'Director': ['N/A'],
#   'Writer': ['N/A'],
#   'Actors': ['Kenneth Branagh']},
#  {'Title': 'WALL·E',
#   'Director': ['Andrew Stanton'],
#   'Writer': ['Andrew Stanton', 'Pete Docter', 'Andrew Stanton', 'Jim Reardon'],
#   'Actors': ['Ben Burtt', 'Elissa Knight', 'Jeff Garlin', 'Fred Willard']},
#  {'Title': 'Wanted',
#   'Director': ['Timur Bekmambetov'],
#   'Writer': ['Michael Brandt',
#    'Derek Haas',
#    'Chris Morgan',
#    'Michael Brandt',
#    'Derek Haas',
#    'Mark Millar',
#    'J.G. Jones'],
#   'Actors': ['James McAvoy',
#    'Morgan Freeman',
#    'Angelina Jolie',
#    'Terence Stamp']},
#  {'Title': 'War for the Planet of the Apes',
#   'Director': ['Matt Reeves'],
#   'Writer': ['Mark Bomback', 'Matt Reeves', 'Rick Jaffa', 'Amanda Silver'],
#   'Actors': ['Andy Serkis', 'Woody Harrelson', 'Steve Zahn', 'Karin Konoval']},
#  {'Title': 'War Horse',
#   'Director': ['Steven Spielberg'],
#   'Writer': ['Lee Hall',
#    'Richard Curtis',
#    'Michael Morpurgo',
#    'Nick Stafford'],
#   'Actors': ['Jeremy Irvine',
#    'Peter Mullan',
#    'Emily Watson',
#    'Niels Arestrup']},
#  {'Title': 'War of the Worlds',
#   'Director': ['Steven Spielberg'],
#   'Writer': ['Josh Friedman', 'David Koepp', 'H.G. Wells'],
#   'Actors': ['Tom Cruise',
#    'Dakota Fanning',
#    'Miranda Otto',
#    'Justin Chatwin']},
#  {'Title': 'Warcraft: The Beginning',
#   'Director': ['Duncan Jones'],
#   'Writer': ['Charles Leavitt', 'Duncan Jones'],
#   'Actors': ['Travis Fimmel', 'Paula Patton', 'Ben Foster', 'Dominic Cooper']},
#  {'Title': 'Watchmen',
#   'Director': ['Zack Snyder'],
#   'Writer': ['David Hayter', 'Alex Tse', 'Dave Gibbons'],
#   'Actors': ['Malin Akerman',
#    'Billy Crudup',
#    'Matthew Goode',
#    'Jackie Earle Haley']},
#  {'Title': 'Waterworld',
#   'Director': ['Kevin Reynolds'],
#   'Writer': ['Peter Rader', 'David Twohy'],
#   'Actors': ['Kevin Costner', 'Chaim Jeraffi', 'Rick Aviles', 'R.D. Call']},
#  {'Title': 'We Were Soldiers',
#   'Director': ['Randall Wallace'],
#   'Writer': ['Harold G. Moore', 'Joseph L. Galloway', 'Randall Wallace'],
#   'Actors': ['Mel Gibson', 'Madeleine Stowe', 'Greg Kinnear', 'Sam Elliott']},
#  {'Title': 'What Dreams May Come',
#   'Director': ['Vincent Ward'],
#   'Writer': ['Richard Matheson', 'Ronald Bass'],
#   'Actors': ['Robin Williams',
#    'Cuba Gooding Jr.',
#    'Annabella Sciorra',
#    'Max von Sydow']},
#  {'Title': 'What Lies Beneath',
#   'Director': ['Robert Zemeckis'],
#   'Writer': ['Clark Gregg', 'Sarah Kernochan', 'Clark Gregg'],
#   'Actors': ['Michelle Pfeiffer',
#    'Katharine Towne',
#    'Miranda Otto',
#    'James Remar']},
#  {'Title': 'What Women Want',
#   'Director': ['Nancy Meyers'],
#   'Writer': ['Josh Goldsmith',
#    'Cathy Yuspa',
#    'Diane Drake',
#    'Josh Goldsmith',
#    'Cathy Yuspa'],
#   'Actors': ['Mel Gibson', 'Helen Hunt', 'Marisa Tomei', 'Alan Alda']},
#  {'Title': 'Where the Wild Things Are',
#   'Director': ['Spike Jonze'],
#   'Writer': ['Spike Jonze', 'Dave Eggers', 'Maurice Sendak'],
#   'Actors': ['Max Records',
#    'Pepita Emmerichs',
#    'Max Pfeifer',
#    'Madeleine Greaves']},
#  {'Title': 'White House Down',
#   'Director': ['Roland Emmerich'],
#   'Writer': ['James Vanderbilt'],
#   'Actors': ['Channing Tatum',
#    'Jamie Foxx',
#    'Maggie Gyllenhaal',
#    'Jason Clarke']},
#  {'Title': 'Who Framed Roger Rabbit',
#   'Director': ['Robert Zemeckis'],
#   'Writer': ['Gary K. Wolf', 'Jeffrey Price', 'Peter S. Seaman'],
#   'Actors': ['Bob Hoskins',
#    'Christopher Lloyd',
#    'Joanna Cassidy',
#    'Charles Fleischer']},
#  {'Title': 'Wild Hogs',
#   'Director': ['Walt Becker'],
#   'Writer': ['Brad Copeland'],
#   'Actors': ['Tim Allen',
#    'John Travolta',
#    'Martin Lawrence',
#    'William H. Macy']},
#  {'Title': 'Windtalkers',
#   'Director': ['John Woo'],
#   'Writer': ['John Rice', 'Joe Batteer'],
#   'Actors': ['Nicolas Cage', 'Adam Beach', 'Peter Stormare', 'Noah Emmerich']},
#  {'Title': 'Wonder Park',
#   'Director': ['Dylan Brown'],
#   'Writer': ['Josh Appelbaum',
#    'André Nemec',
#    'Robert Gordon',
#    'Josh Appelbaum',
#    'André Nemec'],
#   'Actors': ['Sofia Mali',
#    'Jennifer Garner',
#    'Ken Hudson Campbell',
#    'Kenan Thompson']},
#  {'Title': 'Wonder Woman',
#   'Director': ['Patty Jenkins'],
#   'Writer': ['Allan Heinberg',
#    'Zack Snyder',
#    'Allan Heinberg',
#    'Jason Fuchs',
#    'William Moulton Marston'],
#   'Actors': ['Gal Gadot', 'Chris Pine', 'Connie Nielsen', 'Robin Wright']},
#  {'Title': 'World Trade Center',
#   'Director': ['Oliver Stone'],
#   'Writer': ['Andrea Berloff',
#    'John McLoughlin',
#    'Donna McLoughlin',
#    'William Jimeno',
#    'Allison Jimeno'],
#   'Actors': ['Nicolas Cage',
#    'Maria Bello',
#    'Connor Paolo',
#    'Anthony Piccininni']},
#  {'Title': 'World War Z',
#   'Director': ['Marc Forster'],
#   'Writer': ['Matthew Michael Carnahan',
#    'Drew Goddard',
#    'Damon Lindelof',
#    'Matthew Michael Carnahan',
#    'J. Michael Straczynski',
#    'Max Brooks'],
#   'Actors': ['Brad Pitt',
#    'Mireille Enos',
#    'Daniella Kertesz',
#    'James Badge Dale']},
#  {'Title': 'Wrath of the Titans',
#   'Director': ['Jonathan Liebesman'],
#   'Writer': ['Dan Mazeau',
#    'David Leslie Johnson-McGoldrick',
#    'Greg Berlanti',
#    'David Leslie Johnson-McGoldrick',
#    'Dan Mazeau',
#    'Beverley Cross'],
#   'Actors': ['Sam Worthington',
#    'Liam Neeson',
#    'Ralph Fiennes',
#    'Edgar Ramírez']},
#  {'Title': 'Wreck-It Ralph',
#   'Director': ['Rich Moore'],
#   'Writer': ['Rich Moore',
#    'Phil Johnston',
#    'Jim Reardon',
#    'Phil Johnston',
#    'Jennifer Lee',
#    'John C. Reilly',
#    'Sam Levine',
#    'Jared Stern'],
#   'Actors': ['John C. Reilly',
#    'Sarah Silverman',
#    'Jack McBrayer',
#    'Jane Lynch']},
#  {'Title': 'X-Men',
#   'Director': ['Bryan Singer'],
#   'Writer': ['Tom DeSanto', 'Bryan Singer', 'David Hayter'],
#   'Actors': ['Hugh Jackman',
#    'Patrick Stewart',
#    'Ian McKellen',
#    'Famke Janssen']},
#  {'Title': 'X-Men Origins: Wolverine',
#   'Director': ['Gavin Hood'],
#   'Writer': ['David Benioff', 'Skip Woods'],
#   'Actors': ['Hugh Jackman', 'Liev Schreiber', 'Danny Huston', 'Will.i.am']},
#  {'Title': 'X-Men: Apocalypse',
#   'Director': ['Bryan Singer'],
#   'Writer': ['Simon Kinberg',
#    'Bryan Singer',
#    'Simon Kinberg',
#    'Michael Dougherty',
#    'Dan Harris'],
#   'Actors': ['James McAvoy',
#    'Michael Fassbender',
#    'Jennifer Lawrence',
#    'Nicholas Hoult']},
#  {'Title': 'X-Men: Days of Future Past',
#   'Director': ['Bryan Singer'],
#   'Writer': ['Simon Kinberg',
#    'Jane Goldman',
#    'Simon Kinberg',
#    'Matthew Vaughn'],
#   'Actors': ['Hugh Jackman',
#    'James McAvoy',
#    'Michael Fassbender',
#    'Jennifer Lawrence']},
#  {'Title': 'X-Men: First Class',
#   'Director': ['Matthew Vaughn'],
#   'Writer': ['Ashley Miller',
#    'Zack Stentz',
#    'Jane Goldman',
#    'Matthew Vaughn',
#    'Sheldon Turner',
#    'Bryan Singer'],
#   'Actors': ['James McAvoy',
#    'Laurence Belcher',
#    'Michael Fassbender',
#    'Bill Milner']},
#  {'Title': 'X-Men: The Last Stand',
#   'Director': ['Brett Ratner'],
#   'Writer': ['Simon Kinberg', 'Zak Penn'],
#   'Actors': ['Hugh Jackman',
#    'Halle Berry',
#    'Ian McKellen',
#    'Patrick Stewart']},
#  {'Title': 'xXx',
#   'Director': ['Rob Cohen'],
#   'Writer': ['Rich Wilkes'],
#   'Actors': ['Vin Diesel',
#    'Asia Argento',
#    'Marton Csokas',
#    'Samuel L. Jackson']},
#  {'Title': 'xXx: Return of Xander Cage',
#   'Director': ['D.J. Caruso'],
#   'Writer': ['Rich Wilkes', 'F. Scott Frazier'],
#   'Actors': ['Vin Diesel', 'Donnie Yen', 'Deepika Padukone', 'Kris Wu']},
#  {'Title': 'xXx: State of the Union',
#   'Director': ['Lee Tamahori'],
#   'Writer': ['Rich Wilkes', 'Simon Kinberg'],
#   'Actors': ['Willem Dafoe',
#    'Samuel L. Jackson',
#    'Ice Cube',
#    'Scott Speedman']},
#  {'Title': 'Year One',
#   'Director': ['Harold Ramis'],
#   'Writer': ['Harold Ramis',
#    'Gene Stupnitsky',
#    'Lee Eisenberg',
#    'Harold Ramis'],
#   'Actors': ['Jack Black', 'Michael Cera', 'Oliver Platt', 'David Cross']},
#  {'Title': 'Yogi Bear',
#   'Director': ['Eric Brevig'],
#   'Writer': ['J.R. Ventimilia',
#    'Joshua Sternin',
#    'Brad Copeland',
#    'Joseph Barbera',
#    'William Hanna'],
#   'Actors': ['Dan Aykroyd',
#    'Justin Timberlake',
#    'Anna Faris',
#    'Tom Cavanagh']},
#  {'Title': "You Don't Mess with the Zohan",
#   'Director': ['Dennis Dugan'],
#   'Writer': ['Adam Sandler', 'Robert Smigel', 'Judd Apatow'],
#   'Actors': ['Adam Sandler',
#    'John Turturro',
#    'Emmanuelle Chriqui',
#    'Nick Swardson']},
#  {'Title': "You've Got Mail",
#   'Director': ['Nora Ephron'],
#   'Writer': ['Miklós László', 'Nora Ephron', 'Delia Ephron'],
#   'Actors': ['Tom Hanks', 'Meg Ryan', 'Greg Kinnear', 'Parker Posey']},
#  {'Title': 'Zathura: A Space Adventure',
#   'Director': ['Jon Favreau'],
#   'Writer': ['Chris Van Allsburg', 'David Koepp', 'John Kamps'],
#   'Actors': ['Jonah Bobo',
#    'Josh Hutcherson',
#    'Dax Shepard',
#    'Kristen Stewart']},
#  {'Title': 'Zodiac',
#   'Director': ['David Fincher'],
#   'Writer': ['James Vanderbilt', 'Robert Graysmith'],
#   'Actors': ['Jake Gyllenhaal',
#    'Mark Ruffalo',
#    'Anthony Edwards',
#    'Robert Downey Jr.']},
#  {'Title': 'Zookeeper',
#   'Director': ['Frank Coraci'],
#   'Writer': ['Nick Bakay',
#    'Rock Reuben',
#    'Kevin James',
#    'Jay Scherick',
#    'David Ronn',
#    'Jay Scherick',
#    'David Ronn'],
#   'Actors': ['Kevin James', 'Rosario Dawson', 'Leslie Bibb', 'Ken Jeong']},
#  {'Title': 'Zootopia',
#   'Director': ['Byron Howard', 'Rich Moore', 'Jared Bush(co-director)'],
#   'Writer': ['Byron Howard',
#    'Rich Moore',
#    'Jared Bush',
#    'Jim Reardon',
#    'Josie Trinidad',
#    'Phil Johnston',
#    'Jennifer Lee',
#    'Jared Bush',
#    'Phil Johnston'],
#   'Actors': ['Ginnifer Goodwin',
#    'Jason Bateman',
#    'Idris Elba',
#    'Jenny Slate']}]

# %%
# expecting a dictionary and returns a list of tuple for just 1 movie 
def make_people_tuples(movie_dict):    
    retVal = []
    title = movie_dict['Title'] ## why do i need to do this step? wbat would happend if it was not there ?  
    for key in movie_dict.keys():
        if key == 'Director' or key == 'Writer' or key == 'Actors':
            for person in movie_dict[key]:
                retVal.append((person,key,title))
    return retVal

# %%
# does it for all movies 
temp = [] 
for movie in movie_data:
    temp.extend(make_people_tuples(movie))
print(len(temp))
# Out:
# 887

# %%
def add_people(list_of_people):
    for person in list_of_people:
#         print(person)
        cursor.execute("""INSERT IGNORE INTO people (personName,personRole) VALUES (%s,%s)""", person[:2])
        cnx.commit()
    
    for person in list_of_people:
        connect_people_to_movies(person)

# %%
def connect_people_to_movies(person_info):
    # gets movie id's 
    movie_id = movie_titles[titles_only.index(person_info[2])][0] ## movieId of movie
    query = f"""SELECT personId FROM people WHERE personName = "{person_info[0]}" AND personRole = "{person_info[1]}";"""
    cursor.execute(query)
    # getting people id from data 
    person_id = cursor.fetchall()
    #puts into the join table 
    cursor.execute("""INSERT IGNORE INTO movies_people (movieId,personId) VALUES (%s,%s);""",(movie_id,person_id[0][0]))
    cnx.commit()

# %%
for movie in movie_data:
    add_people(make_people_tuples(movie))
# movie_titles
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# <ipython-input-25-b502ce28d896> in <module>
#       1 for movie in movie_data:
# ----> 2     add_people(make_people_tuples(movie))
#       3 # movie_titles
#
# <ipython-input-16-6b58221803a1> in add_people(list_of_people)
#       5 #         cnx.commit()
#       6     for person in list_of_people:
# ----> 7         connect_people_to_movies(person)
#
# <ipython-input-24-d52510218e4e> in connect_people_to_movies(person_info)
#       7     cursor.execute(query)
#       8 #     print("EXECUTED")
# ----> 9     person_id = cursor.fetchall()
#      10 #     print(movie_id,person_id)
#      11     cursor.execute("""INSERT IGNORE INTO movies_people (movieId,personId) VALUES (%s,%s);""",(movie_id,person_id[0][0]))
#
# ~/anaconda3/lib/python3.7/site-packages/mysql/connector/cursor.py in fetchall(self)
#     879     def fetchall(self):
#     880         if not self._have_unread_result():
# --> 881             raise errors.InterfaceError("No result set to fetch from.")
#     882         (rows, eof) = self._connection.get_rows()
#     883         if self._nextrow[0]:
#
# InterfaceError: No result set to fetch from.

# %%
# cursor.execute("""SELECT * FROM people LIMIT 5;""")
cursor.fetchall()
# Out:
# []

# %%
# drop_everything()
# create_table(TABLES)
# Out:
# Creating table people: OK
# Creating table movies_people: OK

# %%
close_connections()
