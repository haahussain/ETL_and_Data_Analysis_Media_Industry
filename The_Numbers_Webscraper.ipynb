# %%
import requests
from bs4 import BeautifulSoup as BS
import config
import mysql.connector
from mysql.connector import errorcode
from datetime import date, datetime, timedelta
import time

headers = {'user-agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3770.100 Safari/537.36'}
numbers_root = 'https://www.the-numbers.com'
db_name = 'Movies'

# %%
def connect_to_AWS():
    cnx = mysql.connector.connect(
        host = config.host,
        user = config.user,
        passwd = config.password
    )
    return cnx

def close_connections():
    cursor.close()
    conn.close()

# %%
# conn = connect_to_AWS()
# cursor = conn.cursor()

# %%
## Function to create new DB 
def create_database(cursor, database_name):
    try:
        cursor.execute(
            "CREATE DATABASE {} DEFAULT CHARACTER SET 'utf8'".format(database_name))
    except mysql.connector.Error as err:
        ## Catch the error if an error occurs.
        print("Failed creating database: {}".format(err))
        exit(1)

## Try to use the database we are creating.
## If we can't use it, then that means the database doesn't exist
    ## Thus we create the database and switch over to it.
try:
    cursor.execute("USE {}".format(db_name))
except mysql.connector.Error as err:
    print("Database {} does not exists.".format(db_name))
    if err.errno == errorcode.ER_BAD_DB_ERROR:
        create_database(cursor, db_name)
        print("Database {} created successfully.".format(db_name))
        conn.database = db_name
    else:
        print(err)
        exit(1)
        
# Function to create tables from a dictionary of tables
# dictionary will have the name of the table as the key and the query to create that table as the value
def create_table(dict_of_tables):
    for table_name in dict_of_tables:
        table_query = dict_of_tables[table_name]
        try:
            print("Creating table {}: ".format(table_name), end='')
            cursor.execute(table_query)
        except mysql.connector.Error as err:
            if err.errno == errorcode.ER_TABLE_EXISTS_ERROR:
                print("already exists.")
            else:
                print(err.msg)
        else:
            print("OK")
        
def drop_tables():
    cursor.execute("""DROP TABLE movies""")
    conn.commit()

# %%
TABLES = {}
TABLES['movies'] = """CREATE TABLE movies (
        movieId INT NOT NULL AUTO_INCREMENT,
        movieTitle varchar(255),
        movieDomGross INT(10),
        movieIntGross INT(10),
        movieBudget INT(10),
        movieRunTime REAL,
        movieAgeRating varchar(10),
        movieReleaseDate DATE,
        movieProdMethod varchar(30),
        movieGenre varchar(20),
        movieType varchar(30),
        PRIMARY KEY (movieId),
        UNIQUE KEY(movieTitle)
    ) ENGINE=InnoDB"""

TABLES['people'] = """

"""

TABLES['movies_people'] = """CREATE TABLE `movie_people` (
  `movieId` INT NOT NULL,
  `personId` INT NOT NULL,
  PRIMARY KEY (`movieId`, `personId`),
  INDEX `movieId_idx` (`movieId` ASC),
  CONSTRAINT `moivieId`
    FOREIGN KEY (`movieId`)
    REFERENCES `Movies`.`movies` (`movieId`)
    ON DELETE CASCADE
    ON UPDATE CASCADE,
  CONSTRAINT `personId`
    FOREIGN KEY (`personId`)
    REFERENCES `Movies`.`people` (`personId`)
    ON DELETE CASCADE
    ON UPDATE CASCADE)
    ENGINE=InnoDB
"""

# %%
# drop_tables()

# %%
# create_table(TABLES)
# # cursor.execute("""ALTER TABLE `Movies`.`movies` AUTO_INCREMENT = 101;""")
# conn.commit()
# Out:
# Creating table movies: already exists.

# %%
def get_soup(url):
    try:
        page = requests.get(url, timeout=5)
    # include code to do status check
        if page.status_code != 200:
            print(page.status_code)
        else:
#             print(page.status_code)
            soup = BS(page.content,'html.parser')
    except requests.ConnectionError as e:
        print("OOPS!! Connection Error. Make sure you are connected to Internet. Technical Details given below.\n")
        print(str(e))
    except requests.Timeout as e:
        print("OOPS!! Timeout Error")
        print(str(e))
    except requests.RequestException as e:
        print("OOPS!! General Error")
        print(str(e))
    except KeyboardInterrupt:
        print("Someone closed the program") 
        
    
    time.sleep(1)
    return soup

# %%
def str_to_int(string):
    return int(string.replace(',','').strip('$'))
    
def str_to_date(string):
    return datetime.strptime(string,"%b %d, %Y").date()

def str_to_time(string):
    return (int(string.strip('minutes')))
    
def get_from_pages(page_start,page_end):
    url = numbers_root+"/movie/budgets/all"
    for page in ['/'+str(num)+'01' for num in range(page_start-1,page_end)]:
        movie_rows = get_movie_rows(url+page)
        for movie_row in movie_rows:
#             print(movie_row)
            movie_info = get_movie_info(movie_row[0])
            if movie_info != 404:
                insert_movie(movie_row[1:]+movie_info)

def get_movie_rows(page_url):
    movie_tuples = []
    soup = get_soup(page_url)
    movie_fins = soup.select('tr td.data')
    movie_exts = soup.select('tr td b a')
    movie_release = soup.select('tr td a')
#     print(movie_release)
#     print(movie_urls)
    for i in range(100):
        ind = i*4
        ind2 = i*2
        if str_to_date(movie_release[ind2].text) < datetime.now().date():
            movie_tuples.append((movie_exts[i]['href'],
                                 movie_exts[i].text,
                                 str_to_date(movie_release[ind2].text),
                                 str_to_int(movie_fins[ind+1].text),
                                 str_to_int(movie_fins[ind+2].text),
                                 str_to_int(movie_fins[ind+3].text)))
    return movie_tuples
#     return [(movie_row['href'],) for movie_row in movie_rows]

## Get runtime, MPAA Rating, Production method, genre, and creative type
def get_movie_info(movie_ext):
    retVal = 404
    try:
        runtime = rating = prod_method = genre = c_type = None
        url = numbers_root + movie_ext
        soup = get_soup(url)
        all_html = soup.select('tr td a')
        full_page = soup.select('tr td')
        
        for time in full_page:
            if time.text.endswith('minutes'):
                runtime = str_to_time(time.text)
                break
        if runtime != None:
            for html in all_html:
                if (rating and prod_method and genre and c_type):
                    retVal = (runtime, rating, prod_method, genre, c_type)

                elif html['href'].startswith('/market/mpaa-rating/'):
                    rating = html.text

                elif html['href'].startswith('/market/genre/'):
                    genre = html.text

                elif html['href'].startswith('/market/production-method/'):
                    prod_method = html.text

                elif html['href'].startswith('/market/creative-type/'):
                    c_type = html.text

        return retVal
    except:
        return retVal
    
def insert_movie(movie_data):
    print(movie_data)
    query = ("""INSERT IGNORE INTO movies
                    (movieTitle,movieReleaseDate,movieBudget,movieDomGross,movieIntGross,
                    movieRunTime,movieAgeRating,movieProdMethod,movieGenre,movieType)
                VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
             """)
    cursor.execute(query,movie_data)
    conn.commit()

# %%
# get_from_pages(5,10)
# Out:
# ('Green Zone', datetime.date(2010, 3, 12), 100000000, 35497337, 97523020, 114, 'R', 'Live Action', 'Drama', 'Historical Fiction')
# ('Geostorm', datetime.date(2017, 10, 20), 100000000, 33700160, 220796009, 109, 'PG-13', 'Live Action', 'Action', 'Science Fiction')
# ('Point Break', datetime.date(2015, 12, 25), 100000000, 28782481, 126704591, 113, 'PG-13', 'Live Action', 'Action', 'Contemporary Fiction')
# ('In the Heart of the Sea', datetime.date(2015, 12, 11), 100000000, 25020758, 89693309, 121, 'PG-13', 'Live Action', 'Adventure', 'Dramatization')
# ('Transcendence', datetime.date(2014, 4, 18), 100000000, 23022309, 103039258, 119, 'PG-13', 'Live Action', 'Thriller/Suspense', 'Science Fiction')
# ('Son of the Mask', datetime.date(2005, 2, 18), 100000000, 17018422, 59918422, 94, 'PG', 'Live Action', 'Adventure', 'Kids Fiction')
# ('Mortal Engines', datetime.date(2018, 12, 14), 100000000, 15951040, 85287417, 128, 'PG-13', 'Live Action', 'Action', 'Science Fiction')
# ('Jin lÃ\xadng shÃ\xad san chai', datetime.date(2012, 1, 20), 100000000, 311434, 98227017, 141, 'R', 'Live Action', 'Drama', 'Historical Fiction')
# ('The Peanuts Movie', datetime.date(2015, 11, 6), 99000000, 130178411, 250091610, 89, 'G', 'Digital Animation', 'Adventure', 'Kids Fiction')
# ('The LEGO Movie 2: The Second Part', datetime.date(2019, 2, 8), 99000000, 105806508, 190209817, 107, 'PG', 'Digital Animation', 'Adventure', 'Kids Fiction')
# ('Robin Hood', datetime.date(2018, 11, 21), 99000000, 30824628, 84747441, 116, 'PG-13', 'Live Action', 'Action', 'Historical Fiction')
# ('The Mummy Returns', datetime.date(2001, 5, 4), 98000000, 202007640, 435040395, 129, 'PG-13', 'Live Action', 'Adventure', 'Fantasy')
# ('Gangs of New York', datetime.date(2002, 12, 20), 97000000, 77730500, 183124621, 155, 'R', 'Live Action', 'Drama', 'Historical Fiction')
# ('Alien: Covenant', datetime.date(2017, 5, 19), 97000000, 74262031, 238521247, 123, 'R', 'Live Action', 'Horror', 'Science Fiction')
# ('Cinderella', datetime.date(2015, 3, 13), 95000000, 201151353, 534551353, 105, 'PG', 'Live Action', 'Drama', 'Fantasy')
# ('Ice Age: Continental Drift', datetime.date(2012, 7, 13), 95000000, 161321843, 879765137, 87, 'PG', 'Digital Animation', 'Adventure', 'Fantasy')
# ('Black Hawk Down', datetime.date(2001, 12, 28), 95000000, 108638745, 159691085, 144, 'R', 'Live Action', 'Action', 'Dramatization')
# ('Sex and the City 2', datetime.date(2010, 5, 27), 95000000, 95347692, 294680778, 146, 'R', 'Live Action', 'Comedy', 'Contemporary Fiction')
# ('Percy Jackson & the Olympians: The Lightning Thief', datetime.date(2010, 2, 12), 95000000, 88768303, 223050874, 119, 'PG', 'Live Action', 'Adventure', 'Fantasy')
# ('The Campaign', datetime.date(2012, 8, 10), 95000000, 86907746, 104907746, 85, 'R', 'Live Action', 'Comedy', 'Contemporary Fiction')
# ('Unstoppable', datetime.date(2010, 11, 12), 95000000, 81562942, 165720921, 98, 'PG-13', 'Live Action', 'Action', 'Dramatization')
# ('The Fifth Element', datetime.date(1997, 5, 9), 95000000, 63570862, 263898761, 126, 'PG-13', 'Live Action', 'Action', 'Science Fiction')
# ('The Road to El Dorado', datetime.date(2000, 3, 31), 95000000, 50802661, 65700000, 89, 'PG', 'Hand Animation', 'Adventure', 'Kids Fiction')
# ('The Lovely Bones', datetime.date(2009, 12, 11), 95000000, 44114232, 94894448, 135, 'PG-13', 'Live Action', 'Drama', 'Contemporary Fiction')
# ('Ben-Hur', datetime.date(2016, 8, 19), 95000000, 26410477, 91669648, 123, 'PG-13', 'Live Action', 'Drama', 'Historical Fiction')
# ('Seventh Son', datetime.date(2015, 2, 6), 95000000, 17725785, 108874967, 102, 'PG-13', 'Live Action', 'Adventure', 'Fantasy')
# ('Finding Nemo', datetime.date(2003, 5, 30), 94000000, 380529370, 936429370, 100, 'G', 'Digital Animation', 'Adventure', 'Kids Fiction')
# ('The Lord of the Rings: The Return of the King', datetime.date(2003, 12, 17), 94000000, 377845905, 1141403341, 201, 'PG-13', 'Animation/Live Action', 'Adventure', 'Fantasy')
# ('The Lord of the Rings: The Two Towers', datetime.date(2002, 12, 18), 94000000, 342548984, 934699645, 179, 'PG-13', 'Animation/Live Action', 'Adventure', 'Fantasy')
# ('Lara Croft: Tomb Raider', datetime.date(2001, 6, 15), 94000000, 131144183, 273330185, 100, 'PG-13', 'Live Action', 'Adventure', 'Contemporary Fiction')
# ('Kingsman: The Secret Service', datetime.date(2015, 2, 13), 94000000, 128261724, 404561724, 129, 'R', 'Live Action', 'Action', 'Contemporary Fiction')
# ('Jurassic Park III', datetime.date(2001, 7, 18), 93000000, 181166115, 365900000, 93, 'PG-13', 'Animation/Live Action', 'Action', 'Science Fiction')
# ('Rise of the Planet of the Apes', datetime.date(2011, 8, 5), 93000000, 176760185, 470986200, 120, 'PG-13', 'Animation/Live Action', 'Adventure', 'Science Fiction')
# ('The Spiderwick Chronicles', datetime.date(2008, 2, 14), 92500000, 71195053, 162839667, 96, 'PG', 'Live Action', 'Adventure', 'Fantasy')
# ('The Incredibles', datetime.date(2004, 11, 5), 92000000, 261441092, 614726752, 115, 'PG', 'Digital Animation', 'Adventure', 'Kids Fiction')
# ('A Good Day to Die Hard', datetime.date(2013, 2, 14), 92000000, 67349198, 304249198, 98, 'R', 'Live Action', 'Action', 'Contemporary Fiction')
# ('The Alamo', datetime.date(2004, 4, 9), 92000000, 22406362, 23911362, 137, 'PG-13', 'Live Action', 'Western', 'Dramatization')
# ('The Secret Life of Walter Mitty', datetime.date(2013, 12, 25), 91000000, 58236838, 187861183, 114, 'PG', 'Live Action', 'Adventure', 'Contemporary Fiction')
# ('Jumanji: Welcome to the Jungle', datetime.date(2017, 12, 20), 90000000, 404508916, 964496193, 119, 'PG-13', 'Live Action', 'Adventure', 'Fantasy')
# ('Men in Black', datetime.date(1997, 7, 1), 90000000, 250690539, 587790539, 98, 'PG-13', 'Live Action', 'Adventure', 'Science Fiction')
# ('Toy Story 2', datetime.date(1999, 11, 19), 90000000, 245852179, 511358276, 92, 'G', 'Digital Animation', 'Adventure', 'Kids Fiction')
# ('Rush Hour 2', datetime.date(2001, 8, 3), 90000000, 226164286, 347425832, 90, 'PG-13', 'Live Action', 'Action', 'Contemporary Fiction')
# ('Sherlock Holmes', datetime.date(2009, 12, 25), 90000000, 209028679, 498438212, 133, 'PG-13', 'Live Action', 'Adventure', 'Historical Fiction')
# ('Ice Age: Dawn of the Dinosaurs', datetime.date(2009, 7, 1), 90000000, 196573705, 859701857, 93, 'PG', 'Digital Animation', 'Adventure', 'Kids Fiction')
# ('Spider-Man: Into The Spider-Verse 3D', datetime.date(2018, 12, 14), 90000000, 190173195, 375380731, 117, 'PG', 'Digital Animation', 'Adventure', 'Super Hero')
# ('What Lies Beneath', datetime.date(2000, 7, 21), 90000000, 155464351, 288693989, 126, 'PG-13', 'Live Action', 'Thriller/Suspense', 'Contemporary Fiction')
# ('Rio', datetime.date(2011, 4, 15), 90000000, 143619809, 487519809, 96, 'G', 'Digital Animation', 'Adventure', 'Kids Fiction')
# ('The Departed', datetime.date(2006, 10, 6), 90000000, 132384315, 289660619, 151, 'R', 'Live Action', 'Drama', 'Contemporary Fiction')
# ("Charlie's Angels", datetime.date(2000, 11, 3), 90000000, 125305545, 259736090, 98, 'PG-13', 'Live Action', 'Action', 'Contemporary Fiction')
# ('Mulan', datetime.date(1998, 6, 19), 90000000, 120620254, 303500000, 87, 'G', 'Hand Animation', 'Adventure', 'Dramatization')
# ('Tropic Thunder', datetime.date(2008, 8, 13), 90000000, 110515313, 191145256, 106, 'R', 'Live Action', 'Comedy', 'Contemporary Fiction')
# ('The Girl with the Dragon Tattoo', datetime.date(2011, 12, 20), 90000000, 102515793, 239373970, 160, 'R', 'Live Action', 'Thriller/Suspense', 'Contemporary Fiction')
# ('Contact', datetime.date(1997, 7, 11), 90000000, 100920329, 165900000, 149, 'PG', 'Live Action', 'Drama', 'Science Fiction')
# ("You Don't Mess With the Zohan", datetime.date(2008, 6, 6), 90000000, 100018837, 202910991, 113, 'PG-13', 'Live Action', 'Comedy', 'Contemporary Fiction')
# ('Die Hard: With a Vengeance', datetime.date(1995, 5, 19), 90000000, 100012499, 366101666, 129, 'R', 'Live Action', 'Action', 'Contemporary Fiction')
# ('The Magnificent Seven', datetime.date(2016, 9, 23), 90000000, 93432655, 162525156, 128, 'PG-13', 'Live Action', 'Western', 'Historical Fiction')
# ('Alvin and the Chipmunks: The Road Chip', datetime.date(2015, 12, 18), 90000000, 85886987, 249517956, 86, 'PG', 'Animation/Live Action', 'Adventure', 'Kids Fiction')
# ('Atlantis: The Lost Empire', datetime.date(2001, 6, 8), 90000000, 84052762, 186049020, 96, 'PG', 'Hand Animation', 'Adventure', 'Kids Fiction')
# ('Valkyrie', datetime.date(2008, 12, 25), 90000000, 83107829, 203932174, 120, 'PG-13', 'Live Action', 'Thriller/Suspense', 'Dramatization')
# ('Pixels', datetime.date(2015, 7, 24), 90000000, 78765986, 244041804, 105, 'PG-13', 'Animation/Live Action', 'Adventure', 'Science Fiction')
# ('Artificial Intelligence: AI', datetime.date(2001, 6, 29), 90000000, 78616689, 235900000, 145, 'PG-13', 'Animation/Live Action', 'Drama', 'Science Fiction')
# ('The Haunted Mansion', datetime.date(2003, 11, 26), 90000000, 75817994, 155750628, 88, 'PG', 'Live Action', 'Adventure', 'Kids Fiction')
# ('The Interpreter', datetime.date(2005, 4, 22), 90000000, 72708161, 162753837, 128, 'PG-13', 'Live Action', 'Thriller/Suspense', 'Contemporary Fiction')
# ('Percy Jackson: Sea of Monsters', datetime.date(2013, 8, 7), 90000000, 68559554, 200859554, 105, 'PG', 'Animation/Live Action', 'Adventure', 'Fantasy')
# ('Lara Croft: Tomb Raider: The Cradle of Life', datetime.date(2003, 7, 25), 90000000, 65653758, 157092943, 117, 'PG-13', 'Live Action', 'Adventure', 'Contemporary Fiction')
# ('Now You See Me 2', datetime.date(2016, 6, 10), 90000000, 65075540, 328325007, 129, 'PG-13', 'Live Action', 'Thriller/Suspense', 'Contemporary Fiction')
# ('Spy Game', datetime.date(2001, 11, 21), 90000000, 62362560, 143049560, 127, 'R', 'Live Action', 'Action', 'Contemporary Fiction')
# ('Tomb Raider', datetime.date(2018, 3, 16), 90000000, 58250803, 273477501, 118, 'PG-13', 'Live Action', 'Action', 'Contemporary Fiction')
# ('Bicentennial Man', datetime.date(1999, 12, 17), 90000000, 58220776, 87420776, 131, 'PG', 'Live Action', 'Drama', 'Science Fiction')
# ('King Arthur', datetime.date(2004, 7, 7), 90000000, 51877963, 203877963, 126, 'PG-13', 'Live Action', 'Adventure', 'Historical Fiction')
# ('Once Upon a Timeâ\x80¦in Hollywood', datetime.date(2019, 7, 26), 90000000, 45718397, 45718397, 159, 'R', 'Live Action', 'Thriller/Suspense', 'Dramatization')
# ("The Devil's Own", datetime.date(1997, 3, 26), 90000000, 42885593, 140900000, 107, 'R', 'Live Action', 'Thriller/Suspense', 'Contemporary Fiction')
# ('K-19: The Widowmaker', datetime.date(2002, 7, 19), 90000000, 35168966, 65716126, 138, 'PG-13', 'Live Action', 'Action', 'Dramatization')
# ('Conan the Barbarian', datetime.date(2011, 8, 19), 90000000, 21295021, 63356133, 112, 'R', 'Live Action', 'Action', 'Fantasy')
# ('The Three Musketeers', datetime.date(2011, 10, 21), 90000000, 20377913, 139877913, 102, 'PG-13', 'Live Action', 'Adventure', 'Historical Fiction')
# ('The Promise', datetime.date(2017, 4, 21), 90000000, 8224288, 10551417, 134, 'PG-13', 'Live Action', 'Drama', 'Historical Fiction')
# ('The Nutcracker in 3D', datetime.date(2010, 11, 24), 90000000, 195459, 20466016, 108, 'PG', 'Animation/Live Action', 'Musical', 'Kids Fiction')
# ('Twister', datetime.date(1996, 5, 10), 88000000, 241688385, 495700000, 114, 'PG-13', 'Live Action', 'Action', 'Contemporary Fiction')
# ('Cinderella Man', datetime.date(2005, 6, 3), 88000000, 61649911, 105021488, 144, 'PG-13', 'Live Action', 'Drama', 'Dramatization')
# ('The Predator', datetime.date(2018, 9, 14), 88000000, 51024708, 159487563, 107, 'R', 'Live Action', 'Action', 'Science Fiction')
# ('Fantastic Four', datetime.date(2005, 7, 8), 87500000, 154696080, 333132750, 106, 'PG-13', 'Live Action', 'Action', 'Super Hero')
# ('Hannibal', datetime.date(2001, 2, 9), 87000000, 165092266, 350100280, 131, 'R', 'Live Action', 'Horror', 'Contemporary Fiction')
# ('Seabiscuit', datetime.date(2003, 7, 25), 86000000, 120277854, 148715342, 140, 'PG-13', 'Live Action', 'Drama', 'Historical Fiction')
# ('Cast Away', datetime.date(2000, 12, 22), 85000000, 233632142, 427230516, 143, 'PG-13', 'Live Action', 'Drama', 'Contemporary Fiction')
# ('Happy Feet', datetime.date(2006, 11, 17), 85000000, 198000317, 385000317, 108, 'PG', 'Digital Animation', 'Adventure', 'Kids Fiction')
# ("Ocean's Eleven", datetime.date(2001, 12, 7), 85000000, 183417150, 450728529, 116, 'PG-13', 'Live Action', 'Thriller/Suspense', 'Contemporary Fiction')
# ('The Bourne Supremacy', datetime.date(2004, 7, 23), 85000000, 176087450, 311001124, 108, 'PG-13', 'Live Action', 'Thriller/Suspense', 'Contemporary Fiction')
# ('Air Force One', datetime.date(1997, 7, 25), 85000000, 172956409, 315268353, 117, 'R', 'Live Action', 'Action', 'Contemporary Fiction')
# ('Fast & Furious', datetime.date(2009, 4, 3), 85000000, 155064265, 363064265, 107, 'PG-13', 'Live Action', 'Action', 'Contemporary Fiction')
# ('Horton Hears a Who', datetime.date(2008, 3, 14), 85000000, 154529439, 299477886, 88, 'G', 'Digital Animation', 'Adventure', 'Fantasy')
# ('Divergent', datetime.date(2014, 3, 21), 85000000, 150947895, 276014965, 140, 'PG-13', 'Live Action', 'Adventure', 'Science Fiction')
# ('Hotel Transylvania', datetime.date(2012, 9, 28), 85000000, 148313048, 378505812, 91, 'PG', 'Digital Animation', 'Adventure', 'Kids Fiction')
# ('Shazam!', datetime.date(2019, 4, 5), 85000000, 140371656, 363664533, 132, 'PG-13', 'Live Action', 'Action', 'Super Hero')
# ('Enchanted', datetime.date(2007, 11, 21), 85000000, 127706877, 340384141, 108, 'PG', 'Animation/Live Action', 'Romantic Comedy', 'Fantasy')
# ('Safe House', datetime.date(2012, 2, 10), 85000000, 126181630, 208542162, 114, 'R', 'Live Action', 'Thriller/Suspense', 'Contemporary Fiction')
# ('I Now Pronounce You Chuck and Larry', datetime.date(2007, 7, 20), 85000000, 119725280, 185708462, 115, 'PG-13', 'Live Action', 'Comedy', 'Contemporary Fiction')
# ("Ocean's Thirteen", datetime.date(2007, 6, 8), 85000000, 117144465, 311744465, 122, 'PG-13', 'Live Action', 'Adventure', 'Contemporary Fiction')
# ('Itâ\x80\x99s Complicated', datetime.date(2009, 12, 25), 85000000, 112735375, 224614744, 118, 'R', 'Live Action', 'Romantic Comedy', 'Contemporary Fiction')
# ('Enemy of the State', datetime.date(1998, 11, 20), 85000000, 111549836, 250649836, 127, 'R', 'Live Action', 'Action', 'Contemporary Fiction')
# ('Open Season', datetime.date(2006, 9, 29), 85000000, 85105259, 191932158, 86, 'PG', 'Digital Animation', 'Adventure', 'Kids Fiction')
# ('Tower Heist', datetime.date(2011, 11, 4), 85000000, 78046570, 150422946, 104, 'PG-13', 'Live Action', 'Comedy', 'Contemporary Fiction')
# ('102 Dalmatians', datetime.date(2000, 11, 22), 85000000, 66941559, 66941559, 100, 'G', 'Live Action', 'Adventure', 'Kids Fiction')
# ('Mirror Mirror', datetime.date(2012, 3, 30), 85000000, 64935167, 173613482, 95, 'PG', 'Live Action', 'Adventure', 'Fantasy')
# ('The Holiday', datetime.date(2006, 12, 8), 85000000, 63280000, 205190324, 135, 'PG-13', 'Live Action', 'Romantic Comedy', 'Contemporary Fiction')
# ('The Fast and the Furious: Tokyo Drift', datetime.date(2006, 6, 16), 85000000, 62615510, 157794205, 104, 'PG-13', 'Live Action', 'Action', 'Contemporary Fiction')
# ('Memoirs of a Geisha', datetime.date(2005, 12, 9), 85000000, 57010853, 161510853, 137, 'PG-13', 'Live Action', 'Drama', 'Historical Fiction')
# ('Enemy at the Gates', datetime.date(2001, 3, 16), 85000000, 51396781, 96971293, 131, 'R', 'Live Action', 'Drama', 'Historical Fiction')
# ('Last Action Hero', datetime.date(1993, 6, 18), 85000000, 50016394, 137298489, 131, 'PG-13', 'Live Action', 'Action', 'Fantasy')
# ('The Rundown', datetime.date(2003, 9, 26), 85000000, 47641743, 80831893, 105, 'PG-13', 'Live Action', 'Action', 'Contemporary Fiction')
# ('Arthur Christmas', datetime.date(2011, 11, 23), 85000000, 46462469, 149717124, 100, 'PG', 'Digital Animation', 'Adventure', 'Kids Fiction')
# ('xXx: Return of Xander Cage', datetime.date(2017, 1, 20), 85000000, 44898413, 345033359, 110, 'PG-13', 'Live Action', 'Action', 'Contemporary Fiction')
# ('Meet Joe Black', datetime.date(1998, 11, 13), 85000000, 44650003, 44650003, 181, 'PG-13', 'Live Action', 'Drama', 'Fantasy')
# ('Cats & Dogs: The Revenge of Kitty Galore', datetime.date(2010, 7, 30), 85000000, 43585753, 113026383, 82, 'PG', 'Live Action', 'Adventure', 'Kids Fiction')
# ('Showtime', datetime.date(2002, 3, 15), 85000000, 37948765, 78948765, 95, 'PG-13', 'Live Action', 'Comedy', 'Contemporary Fiction')
# ('Zodiac', datetime.date(2007, 3, 2), 85000000, 33080084, 83080084, 158, 'R', 'Live Action', 'Thriller/Suspense', 'Dramatization')
# ('Scott Pilgrim vs. The World', datetime.date(2010, 8, 13), 85000000, 31611316, 48056764, 112, 'PG-13', 'Live Action', 'Comedy', 'Contemporary Fiction')
# ('The Core', datetime.date(2003, 3, 28), 85000000, 31111260, 74120792, 137, 'PG-13', 'Live Action', 'Action', 'Science Fiction')
# ('The Greatest Showman', datetime.date(2017, 12, 20), 84000000, 174340174, 386665550, 105, 'PG', 'Live Action', 'Musical', 'Dramatization')
# ('Scooby-Doo', datetime.date(2002, 6, 14), 84000000, 153294164, 276294164, 86, 'PG', 'Live Action', 'Adventure', 'Kids Fiction')
# ('Nutty Professor II: The Klumps', datetime.date(2000, 7, 28), 84000000, 123307945, 166307945, 106, 'PG-13', 'Live Action', 'Comedy', 'Contemporary Fiction')
# ('RED 2', datetime.date(2013, 7, 19), 84000000, 53262560, 141507355, 116, 'PG-13', 'Live Action', 'Action', 'Contemporary Fiction')
# ('Click', datetime.date(2006, 6, 23), 82500000, 137355633, 237685089, 106, 'PG-13', 'Live Action', 'Comedy', 'Fantasy')
# ("Charlotte's Web", datetime.date(2006, 12, 15), 82500000, 82985708, 143985708, 97, 'G', 'Live Action', 'Drama', 'Fantasy')
# ('Jumper', datetime.date(2008, 2, 14), 82500000, 80172128, 222640812, 88, 'PG-13', 'Live Action', 'Adventure', 'Science Fiction')
# ('Hellboy II: The Golden Army', datetime.date(2008, 7, 11), 82500000, 75986503, 160388063, 120, 'PG-13', 'Live Action', 'Action', 'Super Hero')
# ('The Longest Yard', datetime.date(2005, 5, 27), 82000000, 158119460, 191558505, 113, 'PG-13', 'Live Action', 'Comedy', 'Contemporary Fiction')
# ('The Expendables', datetime.date(2010, 8, 13), 82000000, 103068524, 268268174, 103, 'R', 'Live Action', 'Action', 'Contemporary Fiction')
# ('The 6th Day', datetime.date(2000, 11, 17), 82000000, 34543701, 96024898, 124, 'PG-13', 'Live Action', 'Action', 'Science Fiction')
# ('Bruce Almighty', datetime.date(2003, 5, 23), 81000000, 242704995, 484468608, 102, 'PG-13', 'Live Action', 'Comedy', 'Contemporary Fiction')
# ('The Hunger Games', datetime.date(2012, 3, 23), 80000000, 408010692, 677923379, 142, 'PG-13', 'Live Action', 'Thriller/Suspense', 'Science Fiction')
# ('The Hangover Part II', datetime.date(2011, 5, 26), 80000000, 254464305, 586464305, 102, 'R', 'Live Action', 'Comedy', 'Contemporary Fiction')
# ('Mission: Impossible', datetime.date(1996, 5, 21), 80000000, 180981886, 457697994, 111, 'PG-13', 'Live Action', 'Action', 'Contemporary Fiction')
# ('The Lego Batman Movie', datetime.date(2017, 2, 10), 80000000, 175750384, 310660018, 106, 'PG', 'Digital Animation', 'Adventure', 'Kids Fiction')
# ('Hotel Transylvania 2', datetime.date(2015, 9, 25), 80000000, 169700110, 469500298, 89, 'PG', 'Digital Animation', 'Adventure', 'Kids Fiction')
# ('Batman Returns', datetime.date(1992, 6, 18), 80000000, 162833635, 266824291, 126, 'PG-13', 'Live Action', 'Action', 'Super Hero')
# ('The Mummy', datetime.date(1999, 5, 7), 80000000, 155385488, 416385488, 125, 'PG-13', 'Live Action', 'Adventure', 'Fantasy')
# ('Over the Hedge', datetime.date(2006, 5, 19), 80000000, 155019340, 343397247, 84, 'PG', 'Digital Animation', 'Adventure', 'Kids Fiction')
# ('The Secret Life of Pets 2', datetime.date(2019, 6, 7), 80000000, 153918300, 331990024, 92, 'PG', 'Digital Animation', 'Adventure', 'Kids Fiction')
# ('Lilo & Stitch', datetime.date(2002, 6, 21), 80000000, 145771527, 245800000, 85, 'PG', 'Hand Animation', 'Adventure', 'Kids Fiction')
# ('Deep Impact', datetime.date(1998, 5, 8), 80000000, 140464664, 349464664, 123, 'PG-13', 'Live Action', 'Adventure', 'Science Fiction')
# ('Grown Ups 2', datetime.date(2013, 7, 12), 80000000, 133668525, 247023808, 100, 'PG-13', 'Live Action', 'Comedy', 'Contemporary Fiction')
# ('Alvin and the Chipmunks: Chipwrecked', datetime.date(2011, 12, 16), 80000000, 133107389, 349088523, 87, 'G', 'Animation/Live Action', 'Adventure', 'Kids Fiction')
# ('Get Smart', datetime.date(2008, 6, 20), 80000000, 130319208, 226739416, 110, 'PG-13', 'Live Action', 'Comedy', 'Contemporary Fiction')
# ('Robots', datetime.date(2005, 3, 11), 80000000, 128200012, 260700012, 90, 'PG', 'Digital Animation', 'Adventure', 'Kids Fiction')
# ('Shutter Island', datetime.date(2010, 2, 19), 80000000, 128012934, 299461782, 138, 'R', 'Live Action', 'Thriller/Suspense', 'Historical Fiction')
# ("Something's Gotta Give", datetime.date(2003, 12, 12), 80000000, 124685242, 266685242, 123, 'PG-13', 'Live Action', 'Romantic Comedy', 'Contemporary Fiction')
# ('Four Christmases', datetime.date(2008, 11, 26), 80000000, 120146040, 168311558, 88, 'PG-13', 'Live Action', 'Comedy', 'Contemporary Fiction')
# ('Face/Off', datetime.date(1997, 6, 27), 80000000, 112276146, 241200000, 140, 'R', 'Live Action', 'Action', 'Contemporary Fiction')
# ('Bedtime Stories', datetime.date(2008, 12, 25), 80000000, 110101975, 221468935, 99, 'PG', 'Live Action', 'Adventure', 'Fantasy')
# ('Road to Perdition', datetime.date(2002, 7, 12), 80000000, 104054514, 183354514, 116, 'R', 'Live Action', 'Drama', 'Historical Fiction')
# ('Just Go With It', datetime.date(2011, 2, 11), 80000000, 103028109, 214974953, 115, 'PG-13', 'Live Action', 'Romantic Comedy', 'Contemporary Fiction')
# ('Daredevil', datetime.date(2003, 2, 14), 80000000, 102543518, 182782518, 125, 'PG-13', 'Live Action', 'Action', 'Super Hero')
# ('Eagle Eye', datetime.date(2008, 9, 26), 80000000, 101440743, 180585259, 117, 'PG-13', 'Live Action', 'Thriller/Suspense', 'Contemporary Fiction')
# ('Con Air', datetime.date(1997, 6, 6), 80000000, 101117573, 224117573, 115, 'R', 'Live Action', 'Action', 'Contemporary Fiction')
# ('Yogi Bear', datetime.date(2010, 12, 17), 80000000, 100246011, 204774690, 80, 'PG', 'Animation/Live Action', 'Adventure', 'Kids Fiction')
# ('Cold Mountain', datetime.date(2003, 12, 25), 80000000, 95632614, 165173909, 147, 'R', 'Live Action', 'Drama', 'Historical Fiction')
# ('The Book of Eli', datetime.date(2010, 1, 15), 80000000, 94835059, 158750817, 118, 'R', 'Live Action', 'Action', 'Science Fiction')
# ('Flubber', datetime.date(1997, 11, 26), 80000000, 92993801, 177993801, 94, 'PG', 'Live Action', 'Comedy', 'Kids Fiction')
# ('The Haunting', datetime.date(1999, 7, 23), 80000000, 91188905, 180188905, 114, 'PG-13', 'Live Action', 'Horror', 'Contemporary Fiction')
# ('Space Jam', datetime.date(1996, 11, 15), 80000000, 90463534, 250200000, 88, 'PG', 'Animation/Live Action', 'Adventure', 'Kids Fiction')
# ('Fury', datetime.date(2014, 10, 17), 80000000, 85817906, 210315681, 134, 'R', 'Live Action', 'Drama', 'Historical Fiction')
# ('Smallfoot', datetime.date(2018, 9, 28), 80000000, 83240103, 213686569, 96, 'PG', 'Digital Animation', 'Adventure', 'Kids Fiction')
# ('The Pink Panther', datetime.date(2006, 2, 10), 80000000, 82226474, 158926474, 93, 'PG', 'Live Action', 'Adventure', 'Historical Fiction')
# ('Zookeeper', datetime.date(2011, 7, 8), 80000000, 80360866, 170805525, 101, 'PG', 'Animation/Live Action', 'Romantic Comedy', 'Fantasy')
# ('The Day the Earth Stood Still', datetime.date(2008, 12, 12), 80000000, 79366978, 237370350, 103, 'PG-13', 'Live Action', 'Adventure', 'Science Fiction')
# ('Spirit: Stallion of the Cimarron', datetime.date(2002, 5, 24), 80000000, 73215310, 106515310, 84, 'G', 'Hand Animation', 'Adventure', 'Kids Fiction')
# ('Swordfish', datetime.date(2001, 6, 8), 80000000, 69772969, 147080413, 97, 'R', 'Live Action', 'Action', 'Contemporary Fiction')
# ('Fantasia 2000 (Theatrical Release)', datetime.date(1999, 12, 31), 80000000, 69610858, 69618634, 75, 'G', 'Hand Animation', 'Musical', 'Fantasy')
# ('Lost In Space', datetime.date(1998, 4, 3), 80000000, 69117629, 136047317, 130, 'PG-13', 'Live Action', 'Adventure', 'Science Fiction')
# ('The Manchurian Candidate', datetime.date(2004, 7, 30), 80000000, 65948711, 96148711, 130, 'R', 'Live Action', 'Thriller/Suspense', 'Historical Fiction')
# ('DÃ©jÃ\xa0 Vu', datetime.date(2006, 11, 22), 80000000, 64038616, 181038616, 126, 'PG-13', 'Live Action', 'Thriller/Suspense', 'Science Fiction')
# ('Bewitched', datetime.date(2005, 6, 24), 80000000, 63313159, 131159306, 98, 'PG-13', 'Live Action', 'Comedy', 'Fantasy')
# ('The Time Machine', datetime.date(2002, 3, 8), 80000000, 56684819, 98983590, 96, 'PG-13', 'Live Action', 'Adventure', 'Science Fiction')
# ('What Dreams May Come', datetime.date(1998, 10, 2), 80000000, 55485043, 71485043, 113, 'PG-13', 'Live Action', 'Drama', 'Fantasy')
# ('The Legend of Zorro', datetime.date(2005, 10, 28), 80000000, 45575336, 141475336, 126, 'PG', 'Live Action', 'Adventure', 'Historical Fiction')
# ('Little Nicky', datetime.date(2000, 11, 10), 80000000, 39442871, 58270391, 91, 'PG-13', 'Live Action', 'Comedy', 'Fantasy')
# ('Surrogates', datetime.date(2009, 9, 25), 80000000, 38577772, 119668350, 89, 'PG-13', 'Live Action', 'Action', 'Science Fiction')
# ('Evolution', datetime.date(2001, 6, 8), 80000000, 38311134, 98341932, 101, 'PG-13', 'Live Action', 'Comedy', 'Contemporary Fiction')
# ('The Brothers Grimm', datetime.date(2005, 8, 26), 80000000, 37899638, 105299638, 120, 'PG-13', 'Live Action', 'Adventure', 'Fantasy')
# ('Mars Attacks!', datetime.date(1996, 12, 13), 80000000, 37771017, 101371017, 103, 'PG-13', 'Live Action', 'Comedy', 'Science Fiction')
# ('The Wild', datetime.date(2006, 4, 14), 80000000, 37384046, 99010667, 82, 'G', 'Digital Animation', 'Adventure', 'Contemporary Fiction')
# ('Walking with Dinosaurs', datetime.date(2013, 12, 20), 80000000, 36076121, 123368842, 87, 'PG', 'Animation/Live Action', 'Adventure', 'Kids Fiction')
# ('Thirteen Days', datetime.date(2000, 12, 22), 80000000, 34566746, 66554547, 145, 'PG-13', 'Live Action', 'Drama', 'Dramatization')
# ('The Last Witch Hunter', datetime.date(2015, 10, 23), 80000000, 27367660, 130818912, 98, 'PG-13', 'Live Action', 'Action', 'Fantasy')
# ('Pompeii', datetime.date(2014, 2, 21), 80000000, 23169033, 108469033, 102, 'PG-13', 'Live Action', 'Drama', 'Historical Fiction')
# ('Looney Tunes: Back in Action', datetime.date(2003, 11, 14), 80000000, 20950820, 54540662, 91, 'PG', 'Live Action', 'Adventure', 'Kids Fiction')
# ('Nine', datetime.date(2009, 12, 18), 80000000, 19676965, 53508858, 118, 'PG-13', 'Live Action', 'Musical', 'Contemporary Fiction')
# ('Timeline', datetime.date(2003, 11, 26), 80000000, 19480739, 26703184, 116, 'PG-13', 'Live Action', 'Adventure', 'Science Fiction')
# ('Oceans', datetime.date(2010, 4, 22), 80000000, 19422319, 86787530, 84, 'G', 'Live Action', 'Documentary', 'Factual')
# ('Babe: Pig in the City', datetime.date(1998, 11, 25), 80000000, 18319860, 69131860, 96, 'G', 'Live Action', 'Adventure', 'Kids Fiction')
# ('Arthur et les Minimoys', datetime.date(2007, 1, 12), 80000000, 15132763, 113325743, 94, 'PG', 'Animation/Live Action', 'Adventure', 'Fantasy')
# ('The Invasion', datetime.date(2007, 8, 17), 80000000, 15074191, 40147042, 99, 'PG-13', 'Live Action', 'Thriller/Suspense', 'Science Fiction')
# ('A Sound of Thunder', datetime.date(2005, 9, 2), 80000000, 1900451, 6300451, 103, 'PG-13', 'Live Action', 'Action', 'Science Fiction')
# ('The Lion King', datetime.date(1994, 6, 15), 79300000, 421785283, 986214868, 87, 'G', 'Hand Animation', 'Adventure', 'Kids Fiction')
# ('Journey 2: The Mysterious Island', datetime.date(2012, 2, 10), 79000000, 103860290, 318146162, 52, 'PG', 'Live Action', 'Adventure', 'Fantasy')
# ('Jack and Jill', datetime.date(2011, 11, 11), 79000000, 74158157, 150519217, 90, 'PG', 'Live Action', 'Comedy', 'Contemporary Fiction')
# ('A Beautiful Mind', datetime.date(2001, 12, 21), 78000000, 170708996, 317668058, 134, 'PG-13', 'Live Action', 'Drama', 'Dramatization')
# ('Cloudy with a Chance of Meatballs 2', datetime.date(2013, 9, 27), 78000000, 119793567, 274392649, 95, 'PG', 'Digital Animation', 'Adventure', 'Kids Fiction')
# ('Red Dragon', datetime.date(2002, 10, 4), 78000000, 92955420, 206455420, 124, 'R', 'Live Action', 'Thriller/Suspense', 'Contemporary Fiction')
# ('The League of Extraordinary Gentlemen', datetime.date(2003, 7, 11), 78000000, 66465204, 179265204, 110, 'PG-13', 'Live Action', 'Adventure', 'Super Hero')
# ('Exorcist: The Beginning', datetime.date(2004, 8, 20), 78000000, 41814863, 43957541, 114, 'R', 'Live Action', 'Horror', 'Historical Fiction')
# ('The Little Prince', datetime.date(2016, 2, 12), 77500000, 1311213, 102028919, 108, 'PG', 'Digital Animation', 'Adventure', 'Kids Fiction')
# ('Renegades', datetime.date(2019, 1, 22), 77500000, 0, 1521672, 105, 'PG-13', 'Live Action', 'Action', 'Contemporary Fiction')
# ('The Equalizer 2', datetime.date(2018, 7, 20), 77000000, 102084362, 190453132, 129, 'R', 'Live Action', 'Action', 'Contemporary Fiction')
# ('Despicable Me 2', datetime.date(2013, 7, 3), 76000000, 368065385, 975216835, 98, 'PG', 'Digital Animation', 'Adventure', 'Kids Fiction')
# ('2 Fast 2 Furious', datetime.date(2003, 6, 6), 76000000, 127120058, 236410607, 107, 'PG-13', 'Live Action', 'Action', 'Contemporary Fiction')
# ('Children of Men', datetime.date(2006, 12, 25), 76000000, 35552383, 69845011, 109, 'R', 'Live Action', 'Thriller/Suspense', 'Science Fiction')
# ('The Adventures of Rocky & Bullwinkle', datetime.date(2000, 6, 30), 76000000, 26000610, 35129610, 92, 'PG', 'Live Action', 'Adventure', 'Kids Fiction')
# ('The Secret Life of Pets', datetime.date(2016, 7, 8), 75000000, 368384330, 886606412, 91, 'PG', 'Digital Animation', 'Adventure', 'Kids Fiction')
# ('Independence Day', datetime.date(1996, 7, 2), 75000000, 306169255, 817400878, 145, 'PG-13', 'Live Action', 'Adventure', 'Science Fiction')
# ('Dr. Seussâ\x80\x99 The Grinch', datetime.date(2018, 11, 9), 75000000, 270620950, 510987969, 86, 'PG', 'Digital Animation', 'Adventure', 'Kids Fiction')
# ('Sing', datetime.date(2016, 12, 21), 75000000, 270329045, 634454789, 108, 'PG', 'Digital Animation', 'Adventure', 'Kids Fiction')
# ('Despicable Me 3', datetime.date(2017, 6, 30), 75000000, 264624300, 1034727750, 90, 'PG', 'Digital Animation', 'Adventure', 'Kids Fiction')
# ('The Lost World: Jurassic Park', datetime.date(1997, 5, 22), 75000000, 229086679, 618638999, 134, 'PG-13', 'Animation/Live Action', 'Action', 'Science Fiction')
# ('Ice Age: The Meltdown', datetime.date(2006, 3, 31), 75000000, 195330621, 651899282, 91, 'PG', 'Digital Animation', 'Adventure', 'Kids Fiction')
# ('Madagascar', datetime.date(2005, 5, 27), 75000000, 193595521, 556559566, 86, 'PG', 'Digital Animation', 'Adventure', 'Kids Fiction')
# ('Grown Ups', datetime.date(2010, 6, 25), 75000000, 162001186, 272223430, 102, 'PG-13', 'Live Action', 'Comedy', 'Contemporary Fiction')
# ('Shark Tale', datetime.date(2004, 10, 1), 75000000, 161412000, 371917043, 90, 'PG', 'Digital Animation', 'Adventure', 'Kids Fiction')
# ('X-Men', datetime.date(2000, 7, 14), 75000000, 157299717, 296872367, 104, 'PG-13', 'Live Action', 'Action', 'Super Hero')
# ('Wanted', datetime.date(2008, 6, 27), 75000000, 134508551, 342416460, 110, 'R', 'Live Action', 'Action', 'Science Fiction')
# ('The Rock', datetime.date(1996, 6, 7), 75000000, 134069511, 336069511, 136, 'R', 'Live Action', 'Action', 'Contemporary Fiction')
# ('50 First Dates', datetime.date(2004, 2, 13), 75000000, 120776832, 196320329, 96, 'PG-13', 'Live Action', 'Romantic Comedy', 'Contemporary Fiction')
# ('Hairspray', datetime.date(2007, 7, 20), 75000000, 118871849, 203035572, 115, 'PG', 'Live Action', 'Musical', 'Historical Fiction')
# ('Now You See Me', datetime.date(2013, 5, 31), 75000000, 117723989, 342769200, 116, 'PG-13', 'Live Action', 'Thriller/Suspense', 'Contemporary Fiction')
# ('Dreamgirls', datetime.date(2006, 12, 15), 75000000, 103365956, 155708695, 130, 'PG-13', 'Live Action', 'Musical', 'Historical Fiction')
# ('Christopher Robin', datetime.date(2018, 8, 3), 75000000, 99215042, 197504758, 104, 'PG', 'Animation/Live Action', 'Adventure', 'Kids Fiction')
# ('Inspector Gadget', datetime.date(1999, 7, 23), 75000000, 97387965, 97387965, 78, 'PG', 'Live Action', 'Adventure', 'Kids Fiction')
# ('Immortals', datetime.date(2011, 11, 11), 75000000, 83504017, 211562435, 110, 'R', 'Live Action', 'Action', 'Fantasy')
# ('The Terminal', datetime.date(2004, 6, 18), 75000000, 77073959, 218673959, 128, 'PG-13', 'Live Action', 'Drama', 'Dramatization')
# ('Constantine', datetime.date(2005, 2, 18), 75000000, 75976178, 221594911, 121, 'R', 'Live Action', 'Action', 'Contemporary Fiction')
# ('Monster House', datetime.date(2006, 7, 21), 75000000, 73661010, 141267370, 91, 'PG', 'Digital Animation', 'Adventure', 'Kids Fiction')
# ("Charlie Wilson's War", datetime.date(2007, 12, 21), 75000000, 66661095, 119512771, 97, 'R', 'Live Action', 'Drama', 'Dramatization')
# ('Munich', datetime.date(2005, 12, 23), 75000000, 47379090, 131492772, 164, 'R', 'Live Action', 'Drama', 'Dramatization')
# ('Killers', datetime.date(2010, 6, 4), 75000000, 47059963, 95572749, 100, 'PG-13', 'Live Action', 'Action', 'Contemporary Fiction')
# ('The Man From U.N.C.L.E.', datetime.date(2015, 8, 14), 75000000, 45445109, 104949584, 106, 'PG-13', 'Live Action', 'Action', 'Historical Fiction')
# ('Tears of the Sun', datetime.date(2003, 3, 7), 75000000, 43632458, 85632458, 109, 'R', 'Live Action', 'Action', 'Contemporary Fiction')
# ('Lady in the Water', datetime.date(2006, 7, 21), 75000000, 42285169, 72785169, 110, 'PG-13', 'Live Action', 'Drama', 'Fantasy')
# ('Spanglish', datetime.date(2004, 12, 17), 75000000, 42044321, 54344321, 133, 'PG-13', 'Live Action', 'Comedy', 'Contemporary Fiction')
# ('Bandits', datetime.date(2001, 10, 12), 75000000, 41523271, 71523271, 123, 'PG-13', 'Live Action', 'Comedy', 'Contemporary Fiction')
# ('First Knight', datetime.date(1995, 7, 7), 75000000, 37361412, 127361412, 134, 'PG-13', 'Live Action', 'Drama', 'Historical Fiction')
# ('Sucker Punch', datetime.date(2011, 3, 25), 75000000, 36392502, 89758389, 110, 'R', 'Live Action', 'Action', 'Fantasy')
# ('Inferno', datetime.date(2016, 10, 28), 75000000, 34343574, 219519367, 121, 'PG-13', 'Live Action', 'Thriller/Suspense', 'Contemporary Fiction')
# ('Hollywood Homicide', datetime.date(2003, 6, 13), 75000000, 30207785, 50409753, 115, 'PG-13', 'Live Action', 'Action', 'Contemporary Fiction')
# ('Flight of the Phoenix', datetime.date(2004, 12, 17), 75000000, 21009180, 34009180, 113, 'PG-13', 'Live Action', 'Adventure', 'Historical Fiction')
# ('Minions', datetime.date(2015, 7, 10), 74000000, 336045770, 1160336173, 91, 'PG', 'Digital Animation', 'Adventure', 'Kids Fiction')
# ('The SpongeBob Movie: Sponge Out of Water', datetime.date(2015, 2, 6), 74000000, 162994032, 311013181, 93, 'PG', 'Animation/Live Action', 'Adventure', 'Kids Fiction')
# ('Unbreakable', datetime.date(2000, 11, 22), 73243106, 94999143, 248099143, 107, 'PG-13', 'Live Action', 'Thriller/Suspense', 'Super Hero')
# ('Talladega Nights: The Ballad of Ricky Bobby', datetime.date(2006, 8, 4), 73000000, 148213377, 162870525, 104, 'PG-13', 'Live Action', 'Comedy', 'Contemporary Fiction')
# ('The Angry Birds Movie', datetime.date(2016, 5, 20), 73000000, 107509366, 352327887, 97, 'PG', 'Digital Animation', 'Adventure', 'Kids Fiction')
# ('Snake Eyes', datetime.date(1998, 8, 7), 73000000, 55591409, 103891409, 99, 'R', 'Live Action', 'Thriller/Suspense', 'Contemporary Fiction')
# ('Sphere', datetime.date(1998, 2, 13), 73000000, 37068294, 50168294, 128, 'PG-13', 'Live Action', 'Horror', 'Science Fiction')
# ('The Simpsons Movie', datetime.date(2007, 7, 27), 72500000, 183135014, 527071022, 86, 'PG-13', 'Digital Animation', 'Adventure', 'Contemporary Fiction')
# ("Fool's Gold", datetime.date(2008, 2, 8), 72500000, 70231041, 109362966, 112, 'PG-13', 'Live Action', 'Adventure', 'Contemporary Fiction')
# ('Funny People', datetime.date(2009, 7, 31), 72500000, 51855045, 71880305, 146, 'R', 'Live Action', 'Comedy', 'Contemporary Fiction')
# ('The Kingdom', datetime.date(2007, 9, 28), 72500000, 47467250, 86802457, 111, 'R', 'Live Action', 'Action', 'Contemporary Fiction')
# ('Dr. Dolittle 2', datetime.date(2001, 6, 22), 72000000, 112950721, 176101721, 87, 'PG', 'Live Action', 'Adventure', 'Kids Fiction')
# ('Braveheart', datetime.date(1995, 5, 24), 72000000, 75545647, 209045244, 177, 'R', 'Live Action', 'Drama', 'Dramatization')
# ('Jarhead', datetime.date(2005, 11, 4), 72000000, 62647540, 96947540, 122, 'R', 'Live Action', 'Drama', 'Dramatization')
# ('Driven', datetime.date(2001, 4, 27), 72000000, 32616869, 54616869, 117, 'PG-13', 'Live Action', 'Action', 'Contemporary Fiction')
# ('The Majestic', datetime.date(2001, 12, 21), 72000000, 27796042, 37306334, 152, 'PG', 'Live Action', 'Drama', 'Historical Fiction')
# ('Two Brothers', datetime.date(2004, 6, 25), 72000000, 19176754, 62176754, 109, 'PG', 'Live Action', 'Drama', 'Kids Fiction')
# ('The Village', datetime.date(2004, 7, 30), 71682975, 114197520, 257641634, 109, 'PG-13', 'Live Action', 'Thriller/Suspense', 'Contemporary Fiction')
# ('Doctor Dolittle', datetime.date(1998, 6, 26), 71500000, 144156605, 294156605, 85, 'PG-13', 'Live Action', 'Adventure', 'Kids Fiction')
# ('Signs', datetime.date(2002, 8, 2), 70702619, 227969295, 408269295, 106, 'PG-13', 'Live Action', 'Thriller/Suspense', 'Science Fiction')
# ('Shrek 2', datetime.date(2004, 5, 19), 70000000, 441226247, 937008132, 92, 'PG', 'Digital Animation', 'Adventure', 'Kids Fiction')
# ('Cars', datetime.date(2006, 6, 9), 70000000, 244082982, 461651246, 116, 'G', 'Digital Animation', 'Adventure', 'Kids Fiction')
# ('Alvin and the Chipmunks: The Squeakquel', datetime.date(2009, 12, 23), 70000000, 219614612, 443483213, 89, 'PG', 'Animation/Live Action', 'Adventure', 'Kids Fiction')
# ('Who Framed Roger Rabbit?', datetime.date(1988, 6, 22), 70000000, 154112492, 351500000, 103, 'PG', 'Animation/Live Action', 'Adventure', 'Fantasy')
# ('Runaway Bride', datetime.date(1999, 7, 30), 70000000, 152257509, 310138178, 116, 'PG', 'Live Action', 'Romantic Comedy', 'Contemporary Fiction')
# ('xXx', datetime.date(2002, 8, 9), 70000000, 141930000, 267200000, 124, 'PG-13', 'Live Action', 'Action', 'Contemporary Fiction')
# ('Oceanâ\x80\x99s 8', datetime.date(2018, 6, 8), 70000000, 140218711, 297115976, 110, 'PG-13', 'Live Action', 'Action', 'Contemporary Fiction')
# ('Ransom', datetime.date(1996, 11, 8), 70000000, 136492681, 308700000, 121, 'R', 'Live Action', 'Action', 'Contemporary Fiction')
# ('Inglourious Basterds', datetime.date(2009, 8, 21), 70000000, 120774594, 316915264, 152, 'R', 'Live Action', 'Action', 'Historical Fiction')
# ('Hook', datetime.date(1991, 12, 11), 70000000, 119654823, 300854823, 135, 'PG', 'Live Action', 'Adventure', 'Kids Fiction')
# ('Die Hard 2', datetime.date(1990, 7, 3), 70000000, 117323878, 239814025, 124, 'R', 'Live Action', 'Action', 'Contemporary Fiction')
# ('S.W.A.T.', datetime.date(2003, 8, 8), 70000000, 116877597, 207154748, 111, 'PG-13', 'Live Action', 'Action', 'Contemporary Fiction')
# ('Daddyâ\x80\x99s Home 2', datetime.date(2017, 11, 10), 70000000, 104029443, 175807183, 100, 'PG-13', 'Live Action', 'Comedy', 'Contemporary Fiction')
# ('Sleepy Hollow', datetime.date(1999, 11, 19), 70000000, 101068340, 207068340, 105, 'R', 'Live Action', 'Horror', 'Historical Fiction')
# ('Vanilla Sky', datetime.date(2001, 12, 14), 70000000, 100614858, 202726605, 130, 'R', 'Live Action', 'Thriller/Suspense', 'Contemporary Fiction')
# ('Olympus Has Fallen', datetime.date(2013, 3, 22), 70000000, 98927592, 172878928, 120, 'R', 'Live Action', 'Thriller/Suspense', 'Contemporary Fiction')
# ('Battle: Los Angeles', datetime.date(2011, 3, 11), 70000000, 83552429, 213463976, 116, 'PG-13', 'Live Action', 'Action', 'Science Fiction')
# ('War Horse', datetime.date(2011, 12, 25), 70000000, 79883359, 156815529, 146, 'PG-13', 'Live Action', 'Drama', 'Contemporary Fiction')
# ('We Were Soldiers', datetime.date(2002, 3, 1), 70000000, 78120196, 114658262, 139, 'R', 'Live Action', 'Drama', 'Dramatization')
# ('The Monuments Men', datetime.date(2014, 2, 7), 70000000, 78031620, 158702748, 118, 'PG-13', 'Live Action', 'Drama', 'Historical Fiction')
# ('Storks', datetime.date(2016, 9, 23), 70000000, 72679278, 183353431, 100, 'PG', 'Digital Animation', 'Adventure', 'Kids Fiction')
# ('Underworld: Awakening', datetime.date(2012, 1, 20), 70000000, 62321039, 160379930, 89, 'R', 'Live Action', 'Action', 'Fantasy')
# ('The Lego Ninjago Movie', datetime.date(2017, 9, 22), 70000000, 59281555, 122737201, 101, 'PG', 'Digital Animation', 'Adventure', 'Kids Fiction')
# ('Dracula Untold', datetime.date(2014, 10, 10), 70000000, 55991880, 220241723, 92, 'PG-13', 'Live Action', 'Action', 'Fantasy')
# ('The Guardian', datetime.date(2006, 9, 29), 70000000, 55011732, 94973540, 139, 'PG-13', 'Live Action', 'Action', 'Contemporary Fiction')
# ('The Abyss', datetime.date(1989, 8, 9), 70000000, 54243125, 54243125, 140, 'PG-13', 'Live Action', 'Action', 'Science Fiction')
# ('Wall Street 2: Money Never Sleeps', datetime.date(2010, 9, 24), 70000000, 52474616, 137431619, 127, 'PG-13', 'Live Action', 'Drama', 'Contemporary Fiction')
# ('The Dilemma', datetime.date(2011, 1, 14), 70000000, 48475290, 70546865, 110, 'PG-13', 'Live Action', 'Comedy', 'Contemporary Fiction')
# ('Rumor Has It', datetime.date(2005, 12, 25), 70000000, 42996140, 88933562, 96, 'PG-13', 'Live Action', 'Comedy', 'Contemporary Fiction')
# ('The Siege', datetime.date(1998, 11, 6), 70000000, 40934175, 116625798, 120, 'R', 'Live Action', 'Action', 'Contemporary Fiction')
# ('Stardust', datetime.date(2007, 8, 10), 70000000, 38634938, 137022245, 128, 'PG-13', 'Live Action', 'Adventure', 'Fantasy')
# ('Rock of Ages', datetime.date(2012, 6, 15), 70000000, 38518613, 61031932, 123, 'R', 'Live Action', 'Musical', 'Contemporary Fiction')
# ('Seven Years in Tibet', datetime.date(1997, 10, 8), 70000000, 37945884, 131445884, 131, 'PG-13', 'Live Action', 'Drama', 'Dramatization')
# ('Sky Captain and the World of Tomorrow', datetime.date(2004, 9, 17), 70000000, 37760080, 49730854, 107, 'PG', 'Animation/Live Action', 'Adventure', 'Science Fiction')
# ('The Brave One', datetime.date(2007, 9, 14), 70000000, 36793804, 69792704, 122, 'R', 'Live Action', 'Drama', 'Contemporary Fiction')
# ('I Spy', datetime.date(2002, 11, 1), 70000000, 33561137, 60279822, 92, 'PG-13', 'Live Action', 'Action', 'Contemporary Fiction')
# ('Bad Company', datetime.date(2002, 6, 7), 70000000, 30157016, 69157016, 116, 'PG-13', 'Live Action', 'Action', 'Contemporary Fiction')
# ('The Finest Hours', datetime.date(2016, 1, 29), 70000000, 27569558, 49252761, 116, 'PG', 'Live Action', 'Thriller/Suspense', 'Dramatization')
# ('Escape Plan', datetime.date(2013, 10, 18), 70000000, 25135965, 103735965, 115, 'R', 'Live Action', 'Thriller/Suspense', 'Contemporary Fiction')
# ('Killer Elite', datetime.date(2011, 9, 23), 70000000, 25124986, 65409046, 105, 'R', 'Live Action', 'Action', 'Contemporary Fiction')
# ("Hart's War", datetime.date(2002, 2, 15), 70000000, 19076815, 33076815, 128, 'R', 'Live Action', 'Drama', 'Historical Fiction')
# ('Rollerball', datetime.date(2002, 2, 8), 70000000, 18990542, 25852508, 98, 'PG-13', 'Live Action', 'Action', 'Science Fiction')
# ('The Legend of Hercules', datetime.date(2014, 1, 10), 70000000, 18848538, 58953319, 98, 'PG-13', 'Live Action', 'Adventure', 'Fantasy')
# ('Next', datetime.date(2007, 4, 27), 70000000, 18211013, 73591500, 96, 'PG-13', 'Live Action', 'Action', 'Science Fiction')
# ('Osmosis Jones', datetime.date(2001, 8, 10), 70000000, 13596911, 13596911, 95, 'PG', 'Animation/Live Action', 'Adventure', 'Kids Fiction')
# ('Legends of Oz: Dorothyâ\x80\x99s Return', datetime.date(2014, 5, 9), 70000000, 8462347, 20107933, 88, 'PG', 'Digital Animation', 'Adventure', 'Kids Fiction')
# ('Blackhat', datetime.date(2015, 1, 16), 70000000, 8005980, 19665004, 133, 'R', 'Live Action', 'Thriller/Suspense', 'Contemporary Fiction')
# ('Basic Instinct 2', datetime.date(2006, 3, 31), 70000000, 5946136, 35417162, 114, 'R', 'Live Action', 'Thriller/Suspense', 'Contemporary Fiction')
# ('Despicable Me', datetime.date(2010, 7, 9), 69000000, 251513985, 543464573, 95, 'PG', 'Digital Animation', 'Adventure', 'Kids Fiction')
# ('Dinner for Schmucks', datetime.date(2010, 7, 30), 69000000, 73026337, 86796502, 114, 'PG-13', 'Live Action', 'Comedy', 'Contemporary Fiction')
# ('Red Sparrow', datetime.date(2018, 3, 2), 69000000, 46874505, 145951861, 139, 'R', 'Live Action', 'Thriller/Suspense', 'Contemporary Fiction')
# ('The Twilight Saga: Eclipse', datetime.date(2010, 6, 30), 68000000, 300531751, 706102828, 124, 'PG-13', 'Live Action', 'Drama', 'Fantasy')
# ('The Sum of All Fears', datetime.date(2002, 5, 31), 68000000, 118471320, 193500000, 124, 'PG-13', 'Live Action', 'Action', 'Contemporary Fiction')
# ('Ted 2', datetime.date(2015, 6, 26), 68000000, 81476385, 217214143, 115, 'R', 'Live Action', 'Comedy', 'Fantasy')
# ('The Score', datetime.date(2001, 7, 13), 68000000, 71069884, 113542091, 124, 'R', 'Live Action', 'Thriller/Suspense', 'Contemporary Fiction')
# ('Hall Pass', datetime.date(2011, 2, 25), 68000000, 45060734, 87173475, 106, 'R', 'Live Action', 'Comedy', 'Contemporary Fiction')
# ('Dreamcatcher', datetime.date(2003, 3, 21), 68000000, 33685268, 75685268, 133, 'R', 'Live Action', 'Drama', 'Science Fiction')
# ('Mystery Men', datetime.date(1999, 8, 6), 68000000, 29762011, 33462011, 121, 'PG-13', 'Live Action', 'Comedy', 'Super Hero')
# ('The Insider', datetime.date(1999, 11, 5), 68000000, 28965197, 60265197, 158, 'R', 'Live Action', 'Drama', 'Dramatization')
# ('Downsizing', datetime.date(2017, 12, 22), 68000000, 24449754, 54462971, 135, 'R', 'Live Action', 'Comedy', 'Science Fiction')
# ("Doctor Seuss' The Lorax", datetime.date(2012, 3, 2), 67500000, 214030500, 350976753, 101, 'PG', 'Digital Animation', 'Adventure', 'Kids Fiction')
# ('Body of Lies', datetime.date(2008, 10, 10), 67500000, 39394666, 118556530, 128, 'R', 'Live Action', 'Thriller/Suspense', 'Contemporary Fiction')
# ('Abraham Lincoln: Vampire Hunter', datetime.date(2012, 6, 22), 67500000, 37519139, 137489730, 105, 'R', 'Live Action', 'Horror', 'Fantasy')
# ('The Last Legion', datetime.date(2007, 8, 17), 67000000, 5932060, 25357771, 110, 'PG-13', 'Live Action', 'Action', 'Historical Fiction')
# OOPS!! Timeout Error
# HTTPSConnectionPool(host='www.the-numbers.com', port=443): Read timed out. (read timeout=5)
# ('Need for Speed', datetime.date(2014, 3, 14), 66000000, 43568507, 194169619, 130, 'PG-13', 'Live Action', 'Action', 'Contemporary Fiction')
# ('Saving Private Ryan', datetime.date(1998, 7, 24), 65000000, 216335085, 485035085, 169, 'R', 'Live Action', 'Drama', 'Historical Fiction')
# ('What Women Want', datetime.date(2000, 12, 15), 65000000, 182805123, 374105123, 126, 'PG-13', 'Live Action', 'Romantic Comedy', 'Contemporary Fiction')
# ('Lincoln', datetime.date(2012, 11, 9), 65000000, 182207973, 273346281, 149, 'PG-13', 'Live Action', 'Drama', 'Dramatization')
# ('Ice Age', datetime.date(2002, 3, 15), 65000000, 176387405, 386116343, 81, 'PG', 'Digital Animation', 'Adventure', 'Kids Fiction')
# ('Apollo 13', datetime.date(1995, 6, 30), 65000000, 173772767, 335802271, 139, 'PG', 'Live Action', 'Drama', 'Dramatization')
# ('The Matrix', datetime.date(1999, 3, 31), 65000000, 171479930, 463517383, 136, 'R', 'Live Action', 'Action', 'Science Fiction')
# ('Hotel Transylvania 3: Summer Vacation', datetime.date(2018, 7, 13), 65000000, 167500092, 527067879, 97, 'PG', 'Digital Animation', 'Adventure', 'Kids Fiction')
# ('Les Miserables', datetime.date(2012, 12, 25), 65000000, 148809770, 442169052, 158, 'PG-13', 'Live Action', 'Musical', 'Historical Fiction')
# ('The Santa Clause 2', datetime.date(2002, 11, 1), 65000000, 139225854, 172825854, 105, 'G', 'Live Action', 'Adventure', 'Kids Fiction')
# ('Total Recall', datetime.date(1990, 6, 1), 65000000, 119394839, 261400000, 113, 'R', 'Live Action', 'Action', 'Science Fiction')
# ("You've Got Mail", datetime.date(1998, 12, 18), 65000000, 115821495, 250800000, 119, 'PG', 'Live Action', 'Drama', 'Contemporary Fiction')
# ('Unbroken', datetime.date(2014, 12, 25), 65000000, 115637895, 163527824, 137, 'PG-13', 'Live Action', 'Drama', 'Dramatization')
# ('Spy!', datetime.date(2015, 6, 5), 65000000, 110825712, 232585748, 115, 'R', 'Live Action', 'Comedy', 'Contemporary Fiction')
# ...
# ('Eat Pray Love', datetime.date(2010, 8, 13), 60000000, 80574010, 206598789, 134, 'PG-13', 'Live Action', 'Drama', 'Contemporary Fiction')
# ('Jack Reacher', datetime.date(2012, 12, 21), 60000000, 80070736, 217370736, 130, 'PG-13', 'Live Action', 'Drama', 'Contemporary Fiction')
# ('Man on Fire', datetime.date(2004, 4, 23), 60000000, 77906816, 130968579, 146, 'R', 'Live Action', 'Thriller/Suspense', 'Contemporary Fiction')
# ('The Family Man', datetime.date(2000, 12, 22), 60000000, 75764085, 124715863, 125, 'PG-13', 'Live Action', 'Comedy', 'Contemporary Fiction')
# ('Contagion', datetime.date(2011, 9, 9), 60000000, 75658097, 137551594, 105, 'PG-13', 'Live Action', 'Thriller/Suspense', 'Science Fiction')
# ('Any Given Sunday', datetime.date(1999, 12, 22), 60000000, 75530832, 100230832, 164, 'R', 'Live Action', 'Drama', 'Contemporary Fiction')
# ('The Horse Whisperer', datetime.date(1998, 5, 15), 60000000, 75383563, 186883563, 169, 'PG-13', 'Live Action', 'Drama', 'Contemporary Fiction')
# ('Coraline', datetime.date(2009, 2, 6), 60000000, 75286229, 126037057, 100, 'PG', 'Stop-Motion Animation', 'Adventure', 'Kids Fiction')
# ('Deep Blue Sea', datetime.date(1999, 7, 28), 60000000, 73648228, 165048228, 105, 'R', 'Live Action', 'Action', 'Contemporary Fiction')
# ("Michael Jackson's This Is It", datetime.date(2009, 10, 28), 60000000, 72091016, 252091016, 111, 'PG', 'Live Action', 'Documentary', 'Factual')
# ('Kangaroo Jack', datetime.date(2003, 1, 17), 60000000, 66723216, 90723216, 89, 'PG', 'Live Action', 'Adventure', 'Kids Fiction')
# ('The Happening', datetime.date(2008, 6, 13), 60000000, 64506874, 162778384, 90, 'R', 'Live Action', 'Thriller/Suspense', 'Science Fiction')
# ('London Has Fallen', datetime.date(2016, 3, 4), 60000000, 62524260, 195194085, 99, 'R', 'Live Action', 'Thriller/Suspense', 'Contemporary Fiction')
# ('Rules of Engagement', datetime.date(2000, 4, 7), 60000000, 61322858, 71719931, 127, 'R', 'Live Action', 'Thriller/Suspense', 'Contemporary Fiction')
# ('The Shaggy Dog', datetime.date(2006, 3, 10), 60000000, 61123569, 87123569, 98, 'PG', 'Live Action', 'Comedy', 'Fantasy')
# ('Jingle All the Way', datetime.date(1996, 11, 22), 60000000, 60592389, 129832389, 89, 'PG', 'Live Action', 'Adventure', 'Kids Fiction')
# ('Jack Reacher: Never Go Back', datetime.date(2016, 10, 21), 60000000, 58697076, 159946489, 118, 'PG-13', 'Live Action', 'Action', 'Contemporary Fiction')
# ('Baywatch', datetime.date(2017, 5, 25), 60000000, 58060186, 175863783, 119, 'R', 'Live Action', 'Comedy', 'Contemporary Fiction')
# ('A Civil Action', datetime.date(1998, 12, 25), 60000000, 56709981, 56709981, 120, 'PG-13', 'Live Action', 'Drama', 'Contemporary Fiction')
# ('Joy', datetime.date(2015, 12, 25), 60000000, 56451232, 101134059, 124, 'PG-13', 'Live Action', 'Drama', 'Dramatization')
# ('ParaNorman', datetime.date(2012, 8, 17), 60000000, 56003051, 108119662, 96, 'PG', 'Stop-Motion Animation', 'Adventure', 'Kids Fiction')
# ('The Jackal', datetime.date(1997, 11, 14), 60000000, 54956941, 159356941, 124, 'R', 'Live Action', 'Thriller/Suspense', 'Contemporary Fiction')
# ('Paycheck', datetime.date(2003, 12, 25), 60000000, 53789313, 98819789, 115, 'PG-13', 'Live Action', 'Thriller/Suspense', 'Science Fiction')
# ('Up Close & Personal', datetime.date(1996, 3, 1), 60000000, 51045801, 100645801, 124, 'PG-13', 'Live Action', 'Drama', 'Contemporary Fiction')
# ('The Tale of Despereaux', datetime.date(2008, 12, 19), 60000000, 50877145, 90482317, 93, 'G', 'Digital Animation', 'Adventure', 'Kids Fiction')
# ('The Boxtrolls', datetime.date(2014, 9, 26), 60000000, 50837305, 111946251, 96, 'PG', 'Stop-Motion Animation', 'Adventure', 'Kids Fiction')
# ('The Dark Tower', datetime.date(2017, 8, 4), 60000000, 50701325, 113461527, 95, 'PG-13', 'Live Action', 'Western', 'Science Fiction')
# ('The Tuxedo', datetime.date(2002, 9, 27), 60000000, 50586000, 104429625, 98, 'PG-13', 'Live Action', 'Action', 'Science Fiction')
# ('Jack Ryan: Shadow Recruit', datetime.date(2014, 1, 17), 60000000, 50577412, 131377412, 105, 'PG-13', 'Live Action', 'Action', 'Contemporary Fiction')
# ('Miss Congeniality 2: Armed and Fabulous', datetime.date(2005, 3, 24), 60000000, 48478006, 101382396, 115, 'PG-13', 'Live Action', 'Comedy', 'Contemporary Fiction')
# ('Vice', datetime.date(2018, 12, 25), 60000000, 47836282, 70883171, 132, 'R', 'Live Action', 'Black Comedy', 'Dramatization')
# ('Alien: Resurrection', datetime.date(1997, 11, 26), 60000000, 47795018, 160700000, 109, 'R', 'Live Action', 'Action', 'Science Fiction')
# ('Shooter', datetime.date(2007, 3, 23), 60000000, 47003582, 95538560, 126, 'R', 'Live Action', 'Thriller/Suspense', 'Contemporary Fiction')
# ('Practical Magic', datetime.date(1998, 10, 16), 60000000, 46850558, 68336997, 104, 'PG-13', 'Live Action', 'Comedy', 'Fantasy')
# ('Gangster Squad', datetime.date(2013, 1, 11), 60000000, 46000903, 104100903, 110, 'R', 'Live Action', 'Drama', 'Dramatization')
# ('Smurfs: The Lost Village', datetime.date(2017, 4, 7), 60000000, 45020282, 197578586, 90, 'PG', 'Digital Animation', 'Adventure', 'Kids Fiction')
# ('First Man', datetime.date(2018, 10, 12), 60000000, 44936545, 105212037, 141, 'PG-13', 'Live Action', 'Drama', 'Dramatization')
# ('Year One', datetime.date(2009, 6, 19), 60000000, 43337279, 57604723, 97, 'PG-13', 'Live Action', 'Comedy', 'Historical Fiction')
# ('Edge of Darkness', datetime.date(2010, 1, 29), 60000000, 43313890, 82812456, 120, 'R', 'Live Action', 'Drama', 'Contemporary Fiction')
# ('Star Trek: Nemesis', datetime.date(2002, 12, 13), 60000000, 43254409, 67312826, 116, 'PG-13', 'Live Action', 'Adventure', 'Science Fiction')
# ('Planet 51', datetime.date(2009, 11, 20), 60000000, 42194060, 108996113, 97, 'PG', 'Digital Animation', 'Adventure', 'Science Fiction')
# ('Duplicity', datetime.date(2009, 3, 20), 60000000, 40572825, 81079566, 125, 'PG-13', 'Live Action', 'Thriller/Suspense', 'Contemporary Fiction')
# ('Righteous Kill', datetime.date(2008, 9, 12), 60000000, 40081410, 78481410, 110, 'R', 'Live Action', 'Thriller/Suspense', 'Contemporary Fiction')
# ('Invictus', datetime.date(2009, 12, 11), 60000000, 37491364, 124514011, 135, 'PG-13', 'Live Action', 'Drama', 'Dramatization')
# ('State of Play', datetime.date(2009, 4, 17), 60000000, 37017955, 88832210, 127, 'PG-13', 'Live Action', 'Thriller/Suspense', 'Contemporary Fiction')
# ('My Favorite Martian', datetime.date(1999, 2, 12), 60000000, 36850101, 36850101, 94, 'PG', 'Live Action', 'Comedy', 'Science Fiction')
# ('Trouble with the Curve', datetime.date(2012, 9, 21), 60000000, 35763137, 47818913, 111, 'PG-13', 'Live Action', 'Drama', 'Contemporary Fiction')
# ('Intolerable Cruelty', datetime.date(2003, 10, 10), 60000000, 35327628, 121327628, 100, 'PG-13', 'Live Action', 'Romantic Comedy', 'Contemporary Fiction')
# ('Cold Pursuit', datetime.date(2019, 2, 8), 60000000, 32138862, 62599159, 118, 'R', 'Live Action', 'Thriller/Suspense', 'Contemporary Fiction')
# ('Analyze That', datetime.date(2002, 12, 6), 60000000, 32122249, 54994757, 96, 'R', 'Live Action', 'Comedy', 'Contemporary Fiction')
# ('The Soloist', datetime.date(2009, 4, 24), 60000000, 31853584, 38522450, 117, 'PG-13', 'Live Action', 'Drama', 'Dramatization')
# ('The Mortal Instruments: City of Bones', datetime.date(2013, 8, 21), 60000000, 31165421, 75965567, 130, 'PG-13', 'Live Action', 'Adventure', 'Fantasy')
# ('The Legend of Bagger Vance', datetime.date(2000, 11, 3), 60000000, 30695227, 39235486, 123, 'PG-13', 'Live Action', 'Drama', 'Historical Fiction')
# ('Priest', datetime.date(2011, 5, 13), 60000000, 29136626, 84154026, 87, 'PG-13', 'Live Action', 'Horror', 'Fantasy')
# ('Garfield: A Tail of Two Kitties', datetime.date(2006, 6, 16), 60000000, 28426747, 147985373, 86, 'PG', 'Animation/Live Action', 'Adventure', 'Kids Fiction')
# ('XXX: State of the Union', datetime.date(2005, 4, 29), 60000000, 26873932, 71073932, 101, 'PG-13', 'Live Action', 'Action', 'Contemporary Fiction')
# ('Sinbad: Legend of the Seven Seas', datetime.date(2003, 7, 2), 60000000, 26483452, 80767884, 85, 'PG', 'Hand Animation', 'Adventure', 'Kids Fiction')
# ('Dark Water', datetime.date(2005, 7, 8), 60000000, 25473093, 49473093, 105, 'PG-13', 'Live Action', 'Thriller/Suspense', 'Fantasy')
# ('The Black Dahlia', datetime.date(2006, 9, 15), 60000000, 22672813, 49238525, 121, 'R', 'Live Action', 'Thriller/Suspense', 'Historical Fiction')
# ('EDtv', datetime.date(1999, 3, 26), 60000000, 22508689, 35319689, 123, 'PG-13', 'Live Action', 'Comedy', 'Contemporary Fiction')
# ('The Spirit', datetime.date(2008, 12, 25), 60000000, 19806188, 39006188, 102, 'PG-13', 'Live Action', 'Action', 'Super Hero')
# ('The Last Castle', datetime.date(2001, 10, 19), 60000000, 18208078, 20541668, 132, 'R', 'Live Action', 'Drama', 'Contemporary Fiction')
# ('Inkheart', datetime.date(2009, 1, 23), 60000000, 17303424, 66655938, 106, 'PG', 'Live Action', 'Adventure', 'Fantasy')
# ('Supernova', datetime.date(2000, 1, 14), 60000000, 14218868, 14816494, 90, 'PG-13', 'Live Action', 'Action', 'Science Fiction')
# ('Flyboys', datetime.date(2006, 9, 22), 60000000, 13090630, 14816379, 139, 'PG-13', 'Live Action', 'Drama', 'Dramatization')
# ('Winterâ\x80\x99s Tale', datetime.date(2014, 2, 14), 60000000, 12600231, 29575033, 118, 'PG-13', 'Live Action', 'Drama', 'Fantasy')
# ('Holy Man', datetime.date(1998, 10, 9), 60000000, 12069719, 12069719, 113, 'PG', 'Live Action', 'Comedy', 'Contemporary Fiction')
# ('Meet Dave', datetime.date(2008, 7, 11), 60000000, 11803254, 50648806, 90, 'PG', 'Live Action', 'Adventure', 'Science Fiction')
# ('The Great Raid', datetime.date(2005, 8, 12), 60000000, 10166502, 10597070, 132, 'R', 'Live Action', 'Action', 'Historical Fiction')
# ('Rock Dog', datetime.date(2017, 2, 24), 60000000, 9420546, 24148488, 80, 'PG', 'Digital Animation', 'Adventure', 'Kids Fiction')
# ('Mortdecai', datetime.date(2015, 1, 23), 60000000, 7696134, 30396134, 107, 'PG-13', 'Live Action', 'Adventure', 'Contemporary Fiction')
# ('In the Name of the King: A Dungeon Siege Tale', datetime.date(2008, 1, 11), 60000000, 4775656, 13233220, 127, 'PG-13', 'Live Action', 'Action', 'Fantasy')
# ('Xi You Ji zhi Sun Wu Kong San Da Bai Gu Jing', datetime.date(2016, 2, 5), 60000000, 709982, 194058503, 118, 'Not Rated', 'Live Action', 'Action', 'Fantasy')
# ('Sherlock Gnomes', datetime.date(2018, 3, 23), 59000000, 43242871, 87527651, 86, 'PG', 'Digital Animation', 'Adventure', 'Kids Fiction')
# ('The Kid Who Would Be King', datetime.date(2019, 1, 25), 59000000, 16790790, 28296983, 132, 'PG', 'Live Action', 'Adventure', 'Fantasy')
# ('Deadpool', datetime.date(2016, 2, 12), 58000000, 363070709, 801025593, 107, 'R', 'Live Action', 'Action', 'Super Hero')
# ('American Sniper', datetime.date(2014, 12, 25), 58000000, 350126372, 547326372, 132, 'R', 'Live Action', 'Drama', 'Dramatization')
# ('Goosebumps', datetime.date(2015, 10, 16), 58000000, 80069458, 158905324, 103, 'PG', 'Animation/Live Action', 'Horror', 'Fantasy')
# ('Sabrina', datetime.date(1995, 12, 15), 58000000, 53458319, 87100000, 125, 'PG', 'Live Action', 'Romantic Comedy', 'Contemporary Fiction')
# ('Red Tails', datetime.date(2012, 1, 20), 58000000, 49876377, 50365498, 120, 'PG-13', 'Live Action', 'Action', 'Historical Fiction')
# ('Just Like Heaven', datetime.date(2005, 9, 16), 58000000, 48318130, 100687083, 95, 'PG-13', 'Live Action', 'Romantic Comedy', 'Contemporary Fiction')
# ('The Internship', datetime.date(2013, 6, 7), 58000000, 44672764, 93672764, 119, 'PG-13', 'Live Action', 'Comedy', 'Contemporary Fiction')
# ('The Flintstones in Viva Rock Vegas', datetime.date(2000, 4, 28), 58000000, 35231365, 59431365, 90, 'PG', 'Live Action', 'Adventure', 'Kids Fiction')
# ('Leatherheads', datetime.date(2008, 4, 4), 58000000, 31373938, 41348628, 114, 'PG-13', 'Live Action', 'Romantic Comedy', 'Historical Fiction')
# ('Life', datetime.date(2017, 3, 24), 58000000, 30234022, 100929666, 103, 'R', 'Live Action', 'Thriller/Suspense', 'Science Fiction')
# ('Did You Hear About the Morgans?', datetime.date(2009, 12, 18), 58000000, 29580087, 80480566, 103, 'PG-13', 'Live Action', 'Romantic Comedy', 'Contemporary Fiction')
# ('Che, Part 1: The Argentine', datetime.date(2008, 12, 12), 58000000, 1802521, 31627370, 134, 'R', 'Live Action', 'Drama', 'Dramatization')
# ('Sex and the City', datetime.date(2008, 5, 30), 57500000, 152647258, 415247258, 145, 'R', 'Live Action', 'Comedy', 'Contemporary Fiction')
# ('Resident Evil: Afterlife', datetime.date(2010, 9, 10), 57500000, 60128566, 295874190, 97, 'R', 'Live Action', 'Horror', 'Science Fiction')
# ("That's My Boy", datetime.date(2012, 6, 15), 57500000, 36931089, 58085235, 115, 'R', 'Live Action', 'Comedy', 'Contemporary Fiction')
# OOPS!! Timeout Error
# HTTPSConnectionPool(host='www.the-numbers.com', port=443): Read timed out. (read timeout=5)
# ('Ghost Rider: Spirit of Vengeance', datetime.date(2012, 2, 17), 57000000, 51774002, 149217355, 95, 'PG-13', 'Live Action', 'Action', 'Contemporary Fiction')
# ('After the Sunset', datetime.date(2004, 11, 12), 57000000, 28328132, 38329114, 91, 'PG-13', 'Live Action', 'Action', 'Contemporary Fiction')
# ("Captain Corelli's Mandolin", datetime.date(2001, 8, 17), 57000000, 25528495, 62097495, 129, 'R', 'Live Action', 'Drama', 'Historical Fiction')
# ('Into the Woods', datetime.date(2014, 12, 25), 56200000, 128002372, 213116401, 124, 'PG', 'Animation/Live Action', 'Musical', 'Fantasy')
# ('Anger Management', datetime.date(2003, 4, 11), 56000000, 135560942, 195660942, 106, 'PG-13', 'Live Action', 'Comedy', 'Contemporary Fiction')
# ('The Pacifier', datetime.date(2005, 3, 4), 56000000, 113006880, 198006880, 95, 'PG', 'Live Action', 'Comedy', 'Contemporary Fiction')
# ('Walking Tall', datetime.date(2004, 4, 2), 56000000, 46213824, 47313824, 86, 'PG-13', 'Live Action', 'Action', 'Contemporary Fiction')
# ('Zhuo yao ji', datetime.date(2016, 1, 22), 56000000, 32766, 359495591, 118, 'Not Rated', 'Live Action', 'Adventure', 'Fantasy')
# ('Forrest Gump', datetime.date(1994, 7, 6), 55000000, 330151138, 679850637, 142, 'PG-13', 'Live Action', 'Drama', 'Historical Fiction')
# ('Alvin and the Chipmunks', datetime.date(2007, 12, 14), 55000000, 217326974, 362605033, 91, 'PG', 'Animation/Live Action', 'Adventure', 'Kids Fiction')
# ('Bohemian Rhapsody', datetime.date(2018, 11, 2), 55000000, 216303339, 893745898, 134, 'PG-13', 'Live Action', 'Drama', 'Dramatization')
# ('Hitch', datetime.date(2005, 2, 11), 55000000, 177784257, 366784257, 117, 'PG-13', 'Live Action', 'Romantic Comedy', 'Contemporary Fiction')
# ('Meet the Parents', datetime.date(2000, 10, 6), 55000000, 166225040, 330425040, 108, 'PG-13', 'Live Action', 'Comedy', 'Contemporary Fiction')
# ('The Pursuit of Happyness', datetime.date(2006, 12, 15), 55000000, 162586036, 307311093, 117, 'PG-13', 'Live Action', 'Drama', 'Dramatization')
# ('Pocahontas', datetime.date(1995, 6, 10), 55000000, 141579773, 347100000, 81, 'G', 'Hand Animation', 'Adventure', 'Historical Fiction')
# ('Superman', datetime.date(1978, 12, 15), 55000000, 134218018, 300200000, 143, 'PG', 'Live Action', 'Adventure', 'Super Hero')
# ('The Nutty Professor', datetime.date(1996, 6, 28), 55000000, 128814019, 273814019, 95, 'PG-13', 'Live Action', 'Comedy', 'Kids Fiction')
# ('Fifty Shades Darker', datetime.date(2017, 2, 10), 55000000, 114434010, 381398492, 118, 'R', 'Live Action', 'Drama', 'Contemporary Fiction')
# ('Captain Phillips', datetime.date(2013, 10, 11), 55000000, 107136417, 220648184, 133, 'PG-13', 'Live Action', 'Drama', 'Dramatization')
# ('George Of The Jungle', datetime.date(1997, 7, 16), 55000000, 105263257, 174463257, 92, 'PG', 'Live Action', 'Adventure', 'Kids Fiction')
# ('American Wedding', datetime.date(2003, 8, 1), 55000000, 104354205, 126425115, 96, 'R', 'Live Action', 'Comedy', 'Contemporary Fiction')
# ('Murder on the Orient Express', datetime.date(2017, 11, 10), 55000000, 102826543, 345922730, 114, 'PG-13', 'Live Action', 'Drama', 'Historical Fiction')
# ('The Equalizer', datetime.date(2014, 9, 26), 55000000, 101530738, 192903624, 131, 'R', 'Live Action', 'Action', 'Contemporary Fiction')

# %%
# drop_tables()
# create_table(TABLES)
# Out:
# Creating table movies: OK

# %%
# close_connections()
